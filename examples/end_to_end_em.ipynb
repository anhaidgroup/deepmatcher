# %% [markdown]
# # Introduction

# %% [markdown]
# As a part of the ***Magellan*** ecosystem, in this tutorial we will show how to use `deepmatcher` together with `Magellan`, to perform an end-to-end Entity Matching (EM) task. Specifically, `Magellan` performs EM in a **two-stage** fashion where given two tables,
# 1. Perform **blocking** on the two tables by removing obvious non-matching tuple pairs to get a candidate set K.
# 2. Perform **matching** to predict each pair in K as match or non-match. This stage consists of the following substeps:
#     1. *Magellan* first helps the user take a sample S from K.
#     2. The user labels all pairs in S as the training data.
#     3. A classifer L will be learned on S.
#     4. The user applies L to K to predict each pair as match or non-match.
#
# Given the above workflow, `deepmatcher` fits in the step C, which is to take advantage of deep learning to learn a classifer. For the rest of the tutorial, we will use a real example, which is to match songs across two tables from iTunes and Amazon Music, to go through the workflow.
#
# For more information on `Magellan`, please go to the project website: https://sites.google.com/site/anhaidgroup/projects/magellan.

# %% [markdown]
# # Step 0. Preparation
# In order to use ***Magellan***, we need to first install it. The easiest way is to use "pip" as follow (please consult the package website for other installation options).

# %%
try:
    import py_entitymatching as em
except:
    # !pip install py_entitymatching

# %%
import sys

# %%
sys.path.append('/Users/pradap/Documents/Research/Python-Package/anhaid/deepmatcher')

# %%
import deepmatcher as dm
import py_entitymatching as em

import os

# %% [markdown]
# # Step 1. Load data
# We first load the two input tables in the csv format using `Magellan`, that contain songs from iTunes and Amazon Music. These two tables are in the "example" directory included in our package.

# %%
# The path to the two input tables.
path_A = os.path.join('.', 'sample_data', 'itunes-amazon', 'tableA.csv')
path_B = os.path.join('.', 'sample_data', 'itunes-amazon', 'tableB.csv')

# %%
# Load the two tables.
A = em.read_csv_metadata(path_A, key='id')
B = em.read_csv_metadata(path_B, key='id')
# Out:
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.

# %%
# Basic information about the tables.
print('Number of tuples in A: ' + str(len(A)))
print('Number of tuples in B: ' + str(len(B)))
print('Number of tuples in A X B (i.e the cartesian product): ' + str(len(A)*len(B)))
# Out:
# Number of tuples in A: 6907
# Number of tuples in B: 55923
# Number of tuples in A X B (i.e the cartesian product): 386260161

# %%
# The first few tuples in table A.
A.head()
# Out:
#    id                            Song_Name        Artist_Name  \
# 0   0                        Runaway Train                Cam
# 1   1                             Track 14                Omi
# 2   2                       Lips Are Movin     Meghan Trainor
# 3   3  I Want a Hippopotamus for Christmas  A Great Big World
# 4   4                               Credit     Meghan Trainor
#
#                     Album_Name  \
# 0  Welcome to Cam Country - EP
# 1                       Me 4 U
# 2                        Title
# 3  I 'll Be Home For Christmas
# 4             Title ( Deluxe )
#
#                                                  Genre       Price  \
# 0  Country , Music , Contemporary Country , Honky Tonk      $ 0.99
# 1          Pop/Rock , Music , Pop , Dance , R&B / Soul  Album Only
# 2     Pop , Music , Pop/Rock , Dance , Rock , Teen Pop      $ 1.29
# 3                                      Holiday , Music      $ 1.29
# 4     Pop , Music , Rock , Pop/Rock , Dance , Teen Pop      $ 1.29
#
#                                                                                              CopyRight  \
# 0                                                                        2015 Sony Music Entertainment
# 1  2015 Ultra Records , LLC under exclusive license to Columbia Records , a Division of Sony Music ...
# 2                                    2014 , 2015 Epic Records , a division of Sony Music Entertainment
# 3                         Compilation ( P ) 2014 Epic Records , a division of Sony Music Entertainment
# 4                                    2014 , 2015 Epic Records , a division of Sony Music Entertainment
#
#    Time   Released
# 0  3:01  31-Mar-15
# 1  3:41        NaN
# 2  3:01   9-Jan-15
# 3  2:20  24-Nov-14
# 4  2:51   9-Jan-15

# %%
# The first few tuples in table B.
B.head()
# Out:
#    id                          Song_Name Artist_Name  \
# 0   0       Saxophone Stomp [ Explicit ]       Rusko
# 1   1  I Wan na Mingle [ feat . Pusher ]       Rusko
# 2   2                              Lytah       Rusko
# 3   3                       Slappy Pappy       Rusko
# 4   4                        Fushion Jam       Rusko
#
#                     Album_Name                         Genre   Price  \
# 0  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 1  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 2  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 3  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 4  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
#
#                                                                 CopyRight  \
# 0  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 1  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 2  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 3  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 4  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
#
#    Time             Released
# 0  3:20  September 16 , 2014
# 1  2:36  September 16 , 2014
# 2  3:48  September 16 , 2014
# 3  3:55  September 16 , 2014
# 4  1:48  September 16 , 2014

# %% [markdown]
# # Step 2. Block tables to get the candidate set
# We first perform blocking on A and B to get a candidate set K, by removing obvious non-matching tuple pairs. `Magellan` supports four different types of blocker: (1) attribute equivalence, (2) overlap, (3) rule-based, and (4) black-box. Typically, users need to mix and match these blockers with the debugging functionality provided in `Magellan` to get a good candidate set. (Developing a good blocker is not the focus of this tutorial. For more information on developing and debugging a blocker, please consult the user manual of `Magellan`.)
#
# Here we show an example of blocking. Observe that matching tuple pairs should have some common words in the album name, so we first create an overlap blocker on the attribute name "Album_Name" with threshold 2, to remove all pairs with word overlap less 2 in that attribute.

# %%
# Create an overlap blocker in Magellan and apply it to A and B to get the candidate set K1 which is in the format of 
# a dataframe. The "l_out_attrs" and "r_out_attrs" parameters indicate the columns that will be included in K1 from A
# and B respectively.
ob = em.OverlapBlocker()
K1 = ob.block_tables(A, B, 'Album_Name', 'Album_Name',
                    l_output_attrs=['Song_Name', 'Artist_Name', 'Album_Name', 'Genre', 'Price', 'CopyRight', 'Time', 'Released'], 
                    r_output_attrs=['Song_Name', 'Artist_Name', 'Album_Name', 'Genre', 'Price', 'CopyRight', 'Time', 'Released'],
                    overlap_size=2)
# Out:
# /Users/pradap/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py:4388: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /Users/pradap/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py:4389: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:28

# %%
# The number of tuple pairs in K1.
len(K1)
# Out:
# 3152021

# %%
# The first few tuple pairs in K1
K1.head()
# Out:
#    _id  ltable_id  rtable_id ltable_Song_Name ltable_Artist_Name  \
# 0    0       3995          0     Rudolph Blue      Brian Fechino
# 1    1       3995          1     Rudolph Blue      Brian Fechino
# 2    2       3995          2     Rudolph Blue      Brian Fechino
# 3    3       3995          3     Rudolph Blue      Brian Fechino
# 4    4       3995          4     Rudolph Blue      Brian Fechino
#
#                           ltable_Album_Name            ltable_Genre  \
# 0  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 1  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 2  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 3  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 4  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
#
#   ltable_Price ltable_CopyRight ltable_Time ltable_Released  \
# 0       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 1       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 2       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 3       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 4       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
#
#                     rtable_Song_Name rtable_Artist_Name  \
# 0       Saxophone Stomp [ Explicit ]              Rusko
# 1  I Wan na Mingle [ feat . Pusher ]              Rusko
# 2                              Lytah              Rusko
# 3                       Slappy Pappy              Rusko
# 4                        Fushion Jam              Rusko
#
#              rtable_Album_Name                  rtable_Genre rtable_Price  \
# 0  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 1  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 2  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 3  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 4  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
#
#                                                          rtable_CopyRight  \
# 0  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 1  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 2  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 3  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 4  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
#
#   rtable_Time      rtable_Released
# 0        3:20  September 16 , 2014
# 1        2:36  September 16 , 2014
# 2        3:48  September 16 , 2014
# 3        3:55  September 16 , 2014
# 4        1:48  September 16 , 2014

# %% [markdown]
# Notice that K1 has more than 3 million pair in it, which is too large to considered for matching. So we create an overlap blocking with threshold 1 on the attribute "Artist_Name" for K1, to filter all pairs in K1 that don't share any word in "Artist_Name". And we get the candidate set K2.

# %%
# Create a new overlap blocker to remove pairs from K1 that have no common word in "Artist_Name".
K2 = ob.block_candset(K1, 'Artist_Name', 'Artist_Name', overlap_size=1)
# Out:
# /Users/pradap/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py:4388: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /Users/pradap/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py:4389: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:46

# %%
# The number of tuple pairs in K2.
len(K2)
# Out:
# 167180

# %% [markdown]
# After the second blocking step, now we have a candidate set K2 with about 170K pairs. But we think it is still a bit larger to consider for matching. So we apply a third blocker, which is an overlap blocker on the attribute "Song_Name", to further reduce the size of the candidate set.

# %%
# Apply the third overlap blocker.
K3 = ob.block_candset(K2, 'Song_Name', 'Song_Name', overlap_size=1)
# Out:
# /Users/pradap/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py:4388: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /Users/pradap/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py:4389: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:02

# %%
# The number of tuples pairs in K3.
len(K3)
# Out:
# 38015

# %% [markdown]
# Now we have a candidate set with 38K pairs which is reasonable, so we take K3 as the final candidate set. We save the candidate to the disk in the csv format for future reuse.

# %%
path_K = os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial', 'candidate.csv')
K3.to_csv(path_K, index=False)

# %% [markdown]
# # Step 3. Match tuple pairs in the candidate set
# In this stage we will match tuple pairs in the candidate set to predict each of them as match or non-match. This is the part that `deepmatcher` will be involved. Specifically, it consists of the following steps:
# 1. Take a sample S from the candidate set K, and label all pairs in S.
# 2. Train a classifier L using S. Specifically, we will train a classifier using `deepmatcher`.
# 3. Apply L to the candidiate set K.

# %% [markdown]
# ## Sample and label the candidate set
# We first take a random sample S from the candidate set K using `Magellan`. Here for example, we sample 500 pairs for K. Then we label each pair as match (enter 1) or non-match (enter 0) and use S as the training data.

# %%
# Take a sample of 500 pairs from the candidate set.
S = em.sample_table(K3, 500)

# %%
# Label the sample S in a GUI. Enter 1 for match and 0 for non-match.
G = em.label_table(S, 'gold')
# Out:
# WARNING:py_entitymatching.utils.catalog_helper:Column name (gold) is not present in dataframe
# /Users/pradap/miniconda3/lib/python3.6/site-packages/py_entitymatching/gui/table_gui.py:94: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   table.set_value(idxv[i], cols[j], val)

# %% [markdown]
# For the purposes of this tutorial, we will load in a pre-labeled dataset (of 539 tuple pairs) included in this package.

# %%
# The path to the labeled data file.
path_G = os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial', 'gold.csv')

# %%
# Load the labeled data into a dataframe.
G = em.read_csv_metadata(path_G, 
                         key='_id',
                         ltable=A, rtable=B, 
                         fk_ltable='ltable_id', fk_rtable='rtable_id')
print('Number of labeled pairs:', len(G))
# Out:
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.
# Number of labeled pairs: 539

# %% [markdown]
# ## Train a classifier using labeled data
# Once we have the labeled data, we use `deepmatcher` to train a classifier. The first thing we need to do is to split the data for training purpose. In this example, we split the labeled data into three parts: training, validation and test data, with the ratio of 3:1:1. (For now we only support spliting the labeled data into three parts train/valid/test, where the validation set is used for selecting the best model during the training epochs.) For the purpose of caching data and progressive training, we will first save the split parts to disk in the format of csv files, then load them back in. The cache file will be saved during the loading procedure. For subsequent training runs, the cache file will be used to save preprocessing time on the raw csv files, unless the csv files are modified (in this case, new cache file will be generated).

# %%
# The directory where the data splits will be saved.
split_path = os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial')

# %%
# Split labeled data into train, valid, and test csv files to disk, with the split ratio of 3:1:1.
dm.data.split(G, split_path, 'train.csv', 'valid.csv', 'test.csv',
              [3, 1, 1])

# %%
# Load the training data files from the disk. Ignore the "left_id" and "right_id" 
# columns for data preprocessing.
# The 'use_magellan_convention' parameter asks deepmatcher to use Magellan's 
# naming convention for the left and right table column name prefixes 
# ("ltable_", and "rtable_"), and also to consider "_id" as the ID column.
train, validation, test = dm.data.process(
    path=os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial'),
    cache='train_cache.pth',
    train='train.csv',
    validation='valid.csv',
    test='test.csv',
    use_magellan_convention=True,
    ignore_columns=('ltable_id', 'rtable_id'))
# Out:
# Reading and processing data from "./sample_data/itunes-amazon/e2e-tutorial/train.csv"
# 0%                          100%
# [############################# ] | ETA: 00:00:00
# Reading and processing data from "./sample_data/itunes-amazon/e2e-tutorial/valid.csv"
# 0%                          100%
# [############################# ] | ETA: 00:00:00
# Reading and processing data from "./sample_data/itunes-amazon/e2e-tutorial/test.csv"
# 0%                          100%
# [############################# ] | ETA: 00:00:00INFO:deepmatcher.data.field:Downloading vectors from https://drive.google.com/uc?export=download&id=1Vih8gAmgBnuYDxfblbT94P6WjB7s1ZSh
# downloading from Google Drive; may take a few minutes
# /Users/pradap/Documents/Research/Python-Package/anhaid/deepmatcher/deepmatcher/data/field.py:63: ResourceWarning: unclosed <socket.socket fd=73, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('10.141.23.49', 55836), raddr=('172.217.1.46', 443)>
#   download_from_url(url, self.destination)
# /Users/pradap/Documents/Research/Python-Package/anhaid/deepmatcher/deepmatcher/data/field.py:63: ResourceWarning: unclosed <socket.socket fd=74, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=6, laddr=('10.141.23.49', 55837), raddr=('172.217.4.193', 443)>
#   download_from_url(url, self.destination)
# INFO:deepmatcher.data.field:Extracting vectors into /Users/pradap/.vector_cache
#
# Building vocabulary
# 0%  100%
# [#] | ETA: 00:00:00
# Total time elapsed: 00:00:00
#
# Computing principal components
# 0%  100%
# [#] | ETA: 00:00:00
# Total time elapsed: 00:00:00

# %% [markdown]
# After we get the training data, we can use `deepmatcher` to train a classifier. Here we train a hybrid model.

# %%
# Create a hybrid model.
model = dm.MatchingModel(attr_summarizer='hybrid')

# %%
# Train the hybrid model with 10 training epochs, batch size of 16, positive-to-negative 
# ratio to be 3. We save the best model (with the 
# highest F1 score on the validation set) to 'hybrid_model.pth'.
model.run_train(
    train,
    validation,
    epochs=10,
    batch_size=16,
    best_save_path='hybrid_model.pth',
    pos_neg_ratio=3)
# Out:
# 0%  100%
# * Number of trainable parameters: 17757810
# ===>  TRAIN Epoch 1
# [████] | ETA: 00:00:00
# Total time elapsed: 00:00:49
# 0%  100%
# Finished Epoch 1 || Run Time:   53.9 | Load Time:    0.1 || F1:  42.92 | Prec:  32.64 | Rec:  62.67 || Ex/s:   5.98
#
# ===>  EVAL Epoch 1
# [█] | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 1 || Run Time:    6.5 | Load Time:    0.0 || F1:  73.47 | Prec:  81.82 | Rec:  66.67 || Ex/s:  16.45
#
# * Best F1: 73.46938775510203
# Saving best model...
# 0%  100%
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 2
# [████] | ETA: 00:00:00
# Total time elapsed: 00:00:55
# 0%  100%
# Finished Epoch 2 || Run Time:   60.0 | Load Time:    0.1 || F1:  64.33 | Prec:  57.29 | Rec:  73.33 || Ex/s:   5.38
#
# ===>  EVAL Epoch 2
# [█] | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 2 || Run Time:    6.7 | Load Time:    0.0 || F1:  76.36 | Prec:  75.00 | Rec:  77.78 || Ex/s:  15.96
#
# * Best F1: 76.36363636363636
# Saving best model...
# 0%  100%
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 3
# [████] | ETA: 00:00:00
# Total time elapsed: 00:00:55
# 0%  100%
# Finished Epoch 3 || Run Time:   60.4 | Load Time:    0.1 || F1:  80.70 | Prec:  71.88 | Rec:  92.00 || Ex/s:   5.34
#
# ===>  EVAL Epoch 3
# [█] | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 3 || Run Time:    6.6 | Load Time:    0.0 || F1:  86.67 | Prec:  78.79 | Rec:  96.30 || Ex/s:  16.22
#
# * Best F1: 86.66666666666666
# Saving best model...
# 0%  100%
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 4
# [████] | ETA: 00:00:00
# Total time elapsed: 00:00:57
# 0%  100%
# Finished Epoch 4 || Run Time:   62.0 | Load Time:    0.1 || F1:  87.65 | Prec:  81.61 | Rec:  94.67 || Ex/s:   5.20
#
# ===>  EVAL Epoch 4
# [█] | ETA: 00:00:00
# Total time elapsed: 00:00:04
# 0%  100%
# Finished Epoch 4 || Run Time:    6.7 | Load Time:    0.0 || F1:  85.25 | Prec:  76.47 | Rec:  96.30 || Ex/s:  16.04
#
# ---------------------
#
# ===>  TRAIN Epoch 5
# [████] | ETA: 00:00:00
# Total time elapsed: 00:00:59
# 0%  100%
# Finished Epoch 5 || Run Time:   65.7 | Load Time:    0.1 || F1:  94.94 | Prec:  90.36 | Rec: 100.00 || Ex/s:   4.91
#
# ===>  EVAL Epoch 5
# [█] | ETA: 00:00:00
# Total time elapsed: 00:00:05
# Finished Epoch 5 || Run Time:    7.2 | Load Time:    0.0 || F1:  88.14 | Prec:  81.25 | Rec:  96.30 || Ex/s:  14.90
#
# * Best F1: 88.13559322033898
# Saving best model...
# 0%  100%
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 6
# [████] | ETA: 00:00:00
# Total time elapsed: 00:00:57
# 0%  100%
# Finished Epoch 6 || Run Time:   61.6 | Load Time:    0.1 || F1:  98.04 | Prec:  96.15 | Rec: 100.00 || Ex/s:   5.24
#
# ===>  EVAL Epoch 6
# [█] | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 6 || Run Time:    5.8 | Load Time:    0.0 || F1:  89.66 | Prec:  83.87 | Rec:  96.30 || Ex/s:  18.35
#
# * Best F1: 89.6551724137931
# Saving best model...
# 0%  100%
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 7
# [████] | ETA: 00:00:00
# Total time elapsed: 00:00:57
# 0%  100%
# Finished Epoch 7 || Run Time:   61.5 | Load Time:    0.1 || F1:  99.34 | Prec:  98.68 | Rec: 100.00 || Ex/s:   5.24
#
# ===>  EVAL Epoch 7
# [█] | ETA: 00:00:00
# Total time elapsed: 00:00:04
# 0%  100%
# Finished Epoch 7 || Run Time:    6.1 | Load Time:    0.0 || F1:  89.66 | Prec:  83.87 | Rec:  96.30 || Ex/s:  17.50
#
# ---------------------
#
# ===>  TRAIN Epoch 8
# [████] | ETA: 00:00:00
# Total time elapsed: 00:00:50
# 0%  100%
# Finished Epoch 8 || Run Time:   54.5 | Load Time:    0.1 || F1:  99.34 | Prec:  98.68 | Rec: 100.00 || Ex/s:   5.91
#
# ===>  EVAL Epoch 8
# [█] | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 8 || Run Time:    5.9 | Load Time:    0.0 || F1:  91.23 | Prec:  86.67 | Rec:  96.30 || Ex/s:  18.15
#
# * Best F1: 91.2280701754386
# Saving best model...
# 0%  100%
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 9
# [████] | ETA: 00:00:00
# Total time elapsed: 00:00:52
# 0%  100%
# Finished Epoch 9 || Run Time:   57.2 | Load Time:    0.1 || F1: 100.00 | Prec: 100.00 | Rec: 100.00 || Ex/s:   5.63
#
# ===>  EVAL Epoch 9
# [█] | ETA: 00:00:00
# Total time elapsed: 00:00:04
# 0%  100%
# Finished Epoch 9 || Run Time:    6.7 | Load Time:    0.0 || F1:  91.23 | Prec:  86.67 | Rec:  96.30 || Ex/s:  15.92
#
# ---------------------
#
# ===>  TRAIN Epoch 10
# [████] | ETA: 00:00:00
# Total time elapsed: 00:00:57
# 0%  100%
# Finished Epoch 10 || Run Time:   62.4 | Load Time:    0.1 || F1: 100.00 | Prec: 100.00 | Rec: 100.00 || Ex/s:   5.16
#
# ===>  EVAL Epoch 10
# [█] | ETA: 00:00:00
# Total time elapsed: 00:00:05
# Finished Epoch 10 || Run Time:    8.8 | Load Time:    0.0 || F1:  91.23 | Prec:  86.67 | Rec:  96.30 || Ex/s:  12.25
#
# ---------------------
#
# Loading best model...
# Training done.
# 91.2280701754386

# %% [markdown]
# Once we have the trained classifier, we can evaluate the accuracy using the test data.

# %%
# Evaluate the accuracy on the test data.
model.run_eval(test)
# Out:
# 0%  100%
# ===>  EVAL Epoch 8
# Finished Epoch 8 || Run Time:    4.8 | Load Time:    0.0 || F1:  89.66 | Prec:  92.86 | Rec:  86.67 || Ex/s:  22.43
# 89.65517241379311

# %% [markdown]
# ## Apply the trained classifier to the candidate set
# Now we have a trained classifer, we can apply it to the candidate set to predict each pair as match or non-match. To achieve this, we first load the trained model and the candidate set.

# %%
# Load the model.
model = dm.MatchingModel(attr_summarizer='hybrid')
model.load_state('hybrid_model.pth')

# %%
# Load the candidate set. Note that the trained model is an input parameter as we need to trained 
# model for candidate set preprocessing.
candidate = dm.data.process_unlabeled(
    path=os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial', 'candidate.csv'),
    trained_model=model,
    ignore_columns=('ltable_id', 'rtable_id'))
# Out:
# Reading and processing data from "./sample_data/itunes-amazon/e2e-tutorial/candidate.csv"
# 0%                          100%
# [##############################] | ETA: 00:00:00

# %% [markdown]
# After we load the candidate set, now we make the predictions using the `run_prediction` function. The *output_attribute* argument indicates the columns that will be included in the prediction table. Here
# we use all of the columns in the candidate set.

# %%
# Predict the pairs in the candidate set and return a dataframe containing the pair id with 
# the score of being a match.
predictions = model.run_prediction(candidate, output_attributes=list(candidate.get_raw_table().columns))
# Out:
# 0%                          100%
# ===>  PREDICT Epoch 8
# [██████████████████████████████] | ETA: 00:00:00
# Total time elapsed: 00:19:14
# Finished Epoch 8 || Run Time: 1149.7 | Load Time:    8.4 || F1:   0.00 | Prec:   0.00 | Rec:   0.00 || Ex/s:   0.00

# %% [markdown]
# Below shows a few pairs in the prediction table. Note that this table is not sorted in the descending order of the
# match scores.

# %%
predictions.head()
# Out:
#       match_score  ltable_id  rtable_id              ltable_Song_Name  \
# _id
# 3237     0.951813       2583        228  #Selfie ( Instrumental Mix )
# 3274     0.328392       2003        229    #SELFIE ( Caked Up Remix )
# 3275     0.328392       2574        229    #SELFIE ( Caked Up Remix )
# 3276     0.328392       2575        229    #SELFIE ( Caked Up Remix )
# 3359     0.241110       2003        230    #SELFIE ( Caked Up Remix )
#
#      ltable_Artist_Name                      ltable_Album_Name  \
# _id
# 3237   The Chainsmokers  #Selfie ( Instrumental Mix ) - Single
# 3274   The Chainsmokers       #SELFIE ( The Remixes ) - Single
# 3275   The Chainsmokers       #SELFIE ( The Remixes ) - Single
# 3276   The Chainsmokers       #SELFIE ( The Remixes ) - Single
# 3359   The Chainsmokers       #SELFIE ( The Remixes ) - Single
#
#                     ltable_Genre ltable_Price  \
# _id
# 3237  Dance , Music , Electronic       $ 1.29
# 3274  Electronic , Music , Dance       $ 1.29
# 3275  Electronic , Music , Dance       $ 1.29
# 3276  Electronic , Music , Dance       $ 1.29
# 3359  Electronic , Music , Dance       $ 1.29
#
#                                                                                          ltable_CopyRight  \
# _id
# 3237  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , Inc.
# 3274  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3275  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3276  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3359  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
#
#      ltable_Time ltable_Released               rtable_Song_Name  \
# _id
# 3237        3:03       20-Mar-14   #SELFIE ( Instrumental Mix )
# 3274        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3275        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3276        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3359        3:15       17-Jun-14       #Selfie ( Botnek Remix )
#
#      rtable_Artist_Name             rtable_Album_Name  \
# _id
# 3237   The Chainsmokers  #SELFIE ( Instrumental Mix )
# 3274   The Chainsmokers       #Selfie ( The Remixes )
# 3275   The Chainsmokers       #Selfie ( The Remixes )
# 3276   The Chainsmokers       #Selfie ( The Remixes )
# 3359   The Chainsmokers       #Selfie ( The Remixes )
#
#                           rtable_Genre rtable_Price  \
# _id
# 3237                Dance & Electronic       $ 1.29
# 3274  Electronica , Dance & Electronic       $ 1.29
# 3275  Electronica , Dance & Electronic       $ 1.29
# 3276  Electronica , Dance & Electronic       $ 1.29
# 3359  Electronica , Dance & Electronic       $ 1.29
#
#                                                                                          rtable_CopyRight  \
# _id
# 3237  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3274  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3275  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3276  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3359  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
#
#      rtable_Time  rtable_Released
# _id
# 3237        3:03  March 20 , 2014
# 3274        3:52   June 17 , 2014
# 3275        3:52   June 17 , 2014
# 3276        3:52   June 17 , 2014
# 3359        3:36   June 17 , 2014

# %% [markdown]
# We can simply manipulate the prediction table above to get the pairs that we want. Suppose we are only interested in pairs with the match score more over 0.9, and we want to display them sorting in the descending order on match score. This can be achieved as follow.

# %%
high_score_pairs = predictions[predictions['match_score'] >= 0.9].sort_values(by=['match_score'], ascending=False)
high_score_pairs
# Out:
#          match_score  ltable_id  rtable_id  \
# _id
# 2629510     0.999639       5481      48789
# 2629654     0.999639       5481      48801
# 1300688     0.999435       6738      26718
# 812008      0.999386       3974      18994
# 811988      0.999386       3898      18994
# 811989      0.999386       3905      18994
# 812010      0.999386       3976      18994
# 811990      0.999386       3914      18994
# 811991      0.999386       3929      18994
# 812009      0.999386       3975      18994
# 811986      0.999386       3888      18994
# 812007      0.999386       3973      18994
# 812005      0.999386       3971      18994
# 812004      0.999386       3970      18994
# 812006      0.999386       3972      18994
# 1300918     0.999366       6738      26728
# 810156      0.999179       3905      18980
# 810173      0.999179       3972      18980
# 810172      0.999179       3971      18980
# 810171      0.999179       3970      18980
# 810158      0.999179       3929      18980
# 810157      0.999179       3914      18980
# 810175      0.999179       3974      18980
# 810176      0.999179       3975      18980
# 810155      0.999179       3898      18980
# 810153      0.999179       3888      18980
# 810177      0.999179       3976      18980
# 810174      0.999179       3973      18980
# 1652441     0.999103       5684      35061
# 34875       0.998967       2542       1373
# ...              ...        ...        ...
# 1734016     0.901264       5244      36352
# 886937      0.901156       2305      20277
# 886950      0.901156       2325      20277
# 886946      0.901156       2319      20277
# 886944      0.901156       2316      20277
# 886943      0.901156       2315      20277
# 886942      0.901156       2314      20277
# 886941      0.901156       2312      20277
# 886940      0.901156       2311      20277
# 886955      0.901156       2333      20277
# 886954      0.901156       2332      20277
# 886953      0.901156       2331      20277
# 886957      0.901156       2339      20277
# 886952      0.901156       2327      20277
# 886959      0.901156       2343      20277
# 886963      0.901156       2393      20277
# 886951      0.901156       2326      20277
# 886964      0.901156       2476      20277
# 1718093     0.901022       5233      36326
# 1551326     0.900451       5839      32672
# 126341      0.900370       4799       4289
# 446229      0.900252       4364      11509
# 446243      0.900252       4411      11509
# 446247      0.900252       4416      11509
# 446246      0.900252       4415      11509
# 446227      0.900252       4362      11509
# 446245      0.900252       4414      11509
# 446244      0.900252       4412      11509
# 1839704     0.900251       5183      38550
# 1652662     0.900176       5685      35069
#
#                                                     ltable_Song_Name  \
# _id
# 2629510                                                    Talladega
# 2629654                                                    Talladega
# 1300688                                                   Adaptation
# 812008                                                          Dumb
# 811988                                                          Dumb
# 811989                                                          Dumb
# 812010                                                          Dumb
# 811990                                                          Dumb
# 811991                                                          Dumb
# 812009                                                          Dumb
# 811986                                                          Dumb
# 812007                                                          Dumb
# 812005                                                          Dumb
# 812004                                                          Dumb
# 812006                                                          Dumb
# 1300918                                                   Adaptation
# 810156                                                          Dumb
# 810173                                                          Dumb
# 810172                                                          Dumb
# 810171                                                          Dumb
# 810158                                                          Dumb
# 810157                                                          Dumb
# 810175                                                          Dumb
# 810176                                                          Dumb
# 810155                                                          Dumb
# 810153                                                          Dumb
# 810177                                                          Dumb
# 810174                                                          Dumb
# 1652441                                                   Respirator
# 34875                                                        Amnesia
# ...                                                              ...
# 1734016                   Last Chance ( feat . Natasha Bedingfield )
# 886937                                               Ai n't Back Yet
# 886950                                               Ai n't Back Yet
# 886946                                               Ai n't Back Yet
# 886944                                               Ai n't Back Yet
# 886943                                               Ai n't Back Yet
# 886942                                               Ai n't Back Yet
# 886941                                               Ai n't Back Yet
# 886940                                               Ai n't Back Yet
# 886955                                               Ai n't Back Yet
# 886954                                               Ai n't Back Yet
# 886953                                               Ai n't Back Yet
# 886957                                               Ai n't Back Yet
# 886952                                               Ai n't Back Yet
# 886959                                               Ai n't Back Yet
# 886963                                               Ai n't Back Yet
# 886951                                               Ai n't Back Yet
# 886964                                               Ai n't Back Yet
# 1718093                           Roman 's Revenge ( feat . Eminem )
# 1551326  Never Say Never ( feat . Jaden Smith ) [ Acoustic Version ]
# 126341                                               Build Me a Girl
# 446229                                               Dirt Road Diary
# 446243                                               Dirt Road Diary
# 446247                                               Dirt Road Diary
# 446246                                               Dirt Road Diary
# 446227                                               Dirt Road Diary
# 446245                                               Dirt Road Diary
# 446244                                               Dirt Road Diary
# 1839704                                                Paul ( Skit )
# 1652662                Club Ca n't Handle Me ( feat . David Guetta )
#
#                         ltable_Artist_Name  \
# _id
# 2629510                        Eric Church
# 2629654                        Eric Church
# 1300688                         The Weeknd
# 812008                        Jason Derulo
# 811988                        Jason Derulo
# 811989                        Jason Derulo
# 812010                        Jason Derulo
# 811990                        Jason Derulo
# 811991                        Jason Derulo
# 812009                        Jason Derulo
# 811986                        Jason Derulo
# 812007                        Jason Derulo
# 812005                        Jason Derulo
# 812004                        Jason Derulo
# 812006                        Jason Derulo
# 1300918                         The Weeknd
# 810156                        Jason Derulo
# 810173                        Jason Derulo
# 810172                        Jason Derulo
# 810171                        Jason Derulo
# 810158                        Jason Derulo
# 810157                        Jason Derulo
# 810175                        Jason Derulo
# 810176                        Jason Derulo
# 810155                        Jason Derulo
# 810153                        Jason Derulo
# 810177                        Jason Derulo
# 810174                        Jason Derulo
# 1652441                           Flo Rida
# 34875                  5 Seconds of Summer
# ...                                    ...
# 1734016  Nicki Minaj & Natasha Bedingfield
# 886937                       Kenny Chesney
# 886950                       Kenny Chesney
# 886946                       Kenny Chesney
# 886944                       Kenny Chesney
# 886943                       Kenny Chesney
# 886942                       Kenny Chesney
# 886941                       Kenny Chesney
# 886940                       Kenny Chesney
# 886955                       Kenny Chesney
# 886954                       Kenny Chesney
# 886953                       Kenny Chesney
# 886957                       Kenny Chesney
# 886952                       Kenny Chesney
# 886959                       Kenny Chesney
# 886963                       Kenny Chesney
# 886951                       Kenny Chesney
# 886964                       Kenny Chesney
# 1718093               Nicki Minaj & Eminem
# 1551326                      Justin Bieber
# 126341                        Andy Grammer
# 446229                          Luke Bryan
# 446243                          Luke Bryan
# 446247                          Luke Bryan
# 446246                          Luke Bryan
# 446227                          Luke Bryan
# 446245                          Luke Bryan
# 446244                          Luke Bryan
# 1839704                             Eminem
# 1652662                           Flo Rida
#
#                                ltable_Album_Name  \
# _id
# 2629510                            The Outsiders
# 2629654                            The Outsiders
# 1300688                                Kiss Land
# 812008                            Future History
# 811988                            Future History
# 811989                            Future History
# 812010                            Future History
# 811990                            Future History
# 811991                            Future History
# 812009                            Future History
# 811986                            Future History
# 812007                            Future History
# 812005                            Future History
# 812004                            Future History
# 812006                            Future History
# 1300918                                Kiss Land
# 810156                            Future History
# 810173                            Future History
# 810172                            Future History
# 810171                            Future History
# 810158                            Future History
# 810157                            Future History
# 810175                            Future History
# 810176                            Future History
# 810155                            Future History
# 810153                            Future History
# 810177                            Future History
# 810174                            Future History
# 1652441  Only One Flo , Pt. 1 ( Deluxe Version )
# 34875                        5 Seconds of Summer
# ...                                          ...
# 1734016                              Pink Friday
# 886937                          Greatest Hits II
# 1718093  Roman 's Revenge ( Album Version ( Edited ) ) [ feat . Eminem ] [ Clean ]
# 1551326                Never Say Never ( Acoustic Version ) [ feat . Jaden Smith ]
# 126341                                                             Build Me A Girl
# 446229                                                             Dirt Road Diary
# 446243                                                             Dirt Road Diary
# 446247                                                             Dirt Road Diary
# 446246                                                             Dirt Road Diary
# 446227                                                             Dirt Road Diary
# 446245                                                             Dirt Road Diary
# 446244                                                             Dirt Road Diary
# 1839704                                                 Paul ( Skit ) [ Explicit ]
# 1652662                                                  21 ( Feat . Laza Morgan )
#
#           rtable_Artist_Name  \
# _id
# 2629510          Eric Church
# 2629654          Eric Church
# 1300688           The Weeknd
# 812008          Jason Derulo
# 811988          Jason Derulo
# 811989          Jason Derulo
# 812010          Jason Derulo
# 811990          Jason Derulo
# 811991          Jason Derulo
# 812009          Jason Derulo
# 811986          Jason Derulo
# 812007          Jason Derulo
# 812005          Jason Derulo
# 812004          Jason Derulo
# 812006          Jason Derulo
# 1300918           The Weeknd
# 810156          Jason Derulo
# 810173          Jason Derulo
# 810172          Jason Derulo
# 810171          Jason Derulo
# 810158          Jason Derulo
# 810157          Jason Derulo
# 810175          Jason Derulo
# 810176          Jason Derulo
# 810155          Jason Derulo
# 810153          Jason Derulo
# 810177          Jason Derulo
# 810174          Jason Derulo
# 1652441             Flo Rida
# 34875    5 Seconds Of Summer
# ...                      ...
# 1734016          Nicki Minaj
# 886937         Kenny Chesney
# 886950         Kenny Chesney
# 886946         Kenny Chesney
# 886944         Kenny Chesney
# 886943         Kenny Chesney
# 886942         Kenny Chesney
# 886941         Kenny Chesney
# 886940         Kenny Chesney
# 886955         Kenny Chesney
# 886954         Kenny Chesney
# 886953         Kenny Chesney
# 886957         Kenny Chesney
# 886952         Kenny Chesney
# 886959         Kenny Chesney
# 886963         Kenny Chesney
# 886951         Kenny Chesney
# 886964         Kenny Chesney
# 1718093          Nicki Minaj
# 1551326        Justin Bieber
# 126341          Andy Grammer
# 446229            Luke Bryan
# 446243            Luke Bryan
# 446247            Luke Bryan
# 446246            Luke Bryan
# 446227            Luke Bryan
# 446245            Luke Bryan
# 446244            Luke Bryan
# 1839704               Eminem
# 1652662             Flo Rida
#
#                                                             rtable_Album_Name  \
# _id
# 2629510                                                         The Outsiders
# 2629654                                                         The Outsiders
# 1300688                                                   Kiss Land [ Clean ]
# 812008                                                         Future History
# 811988                                                         Future History
# 811989                                                         Future History
# 812010                                                         Future History
# 811990                                                         Future History
# 811991                                                         Future History
# 812009                                                         Future History
# 811986                                                         Future History
# 812007                                                         Future History
# 812005                                                         Future History
# 812004                                                         Future History
# 812006                                                         Future History
# 1300918                                                Kiss Land [ Explicit ]
# 810156                                      Future History ( Deluxe Version )
# 810173                                      Future History ( Deluxe Version )
# 810172                                      Future History ( Deluxe Version )
# 810171                                      Future History ( Deluxe Version )
# 810158                                      Future History ( Deluxe Version )
# 810157                                      Future History ( Deluxe Version )
# 810175                                      Future History ( Deluxe Version )
# 810176                                      Future History ( Deluxe Version )
# 810155                                      Future History ( Deluxe Version )
# 810153                                      Future History ( Deluxe Version )
# 810177                                      Future History ( Deluxe Version )
# 810174                                      Future History ( Deluxe Version )
# 1652441  Only One Flo ( Part 1 ) [ Deluxe ] [ + Video ] [ + Digital Booklet ]
# 34875                                                     5 Seconds Of Summer
# ...                                                                       ...
# 1734016                           Pink Friday ( Deluxe Version ) [ Explicit ]
# 886937                                                          Greatest Hits
# 886950                                                          Greatest Hits
# 886946                                                          Greatest Hits
# 886944                                                          Greatest Hits
# 886943                                                          Greatest Hits
# 886942                                                          Greatest Hits
# 886941                                                          Greatest Hits
# 886940                                                          Greatest Hits
# 886955                                                          Greatest Hits
# 886954                                                          Greatest Hits
# 886953                                                          Greatest Hits
# 886957                                                          Greatest Hits
# 886952                                                          Greatest Hits
# 886959                                                          Greatest Hits
# 886963                                                          Greatest Hits
# 886951                                                          Greatest Hits
# 886964                                                          Greatest Hits
# 1718093                                        Pink Friday ( Deluxe Version )
# 1551326                  My Worlds Acoustic [ + Video ] [ + Digital Booklet ]
# 126341                         Andy Grammer [ + Video ] [ + Digital Booklet ]
# 446229                                      Crash My Party ( Deluxe Version )
# 446243                                      Crash My Party ( Deluxe Version )
# 446247                                      Crash My Party ( Deluxe Version )
# 446246                                      Crash My Party ( Deluxe Version )
# 446227                                      Crash My Party ( Deluxe Version )
# 446245                                      Crash My Party ( Deluxe Version )
# 446244                                      Crash My Party ( Deluxe Version )
# 1839704                                         Relapse : Refill [ Explicit ]
# 1652662                                               Only One Flo ( Part 1 )
#
#                    rtable_Genre rtable_Price  \
# _id
# 2629510                 Country       $ 1.29
# 2629654                 Country       $ 1.29
# 1300688                     R&B       $ 1.29
# 812008                      Pop       $ 1.29
# 811988                      Pop       $ 1.29
# 811989                      Pop       $ 1.29
# 812010                      Pop       $ 1.29
# 811990                      Pop       $ 1.29
# 811991                      Pop       $ 1.29
# 812009                      Pop       $ 1.29
# 811986                      Pop       $ 1.29
# 812007                      Pop       $ 1.29
# 812005                      Pop       $ 1.29
# 812004                      Pop       $ 1.29
# 812006                      Pop       $ 1.29
# 1300918                     R&B       $ 1.29
# 810156                      Pop       $ 1.29
# 810173                      Pop       $ 1.29
# 810172                      Pop       $ 1.29
# 810171                      Pop       $ 1.29
# 810158                      Pop       $ 1.29
# 810157                      Pop       $ 1.29
# 810175                      Pop       $ 1.29
# 810176                      Pop       $ 1.29
# 810155                      Pop       $ 1.29
# 810153                      Pop       $ 1.29
# 810177                      Pop       $ 1.29
# 810174                      Pop       $ 1.29
# 1652441           Rap & Hip-Hop       $ 1.29
# 34875                       Pop       $ 1.29
# ...                         ...          ...
# 1734016  R&B , Contemporary R&B       $ 1.29
# 886937                  Country       $ 1.29
# 886950                  Country       $ 1.29
# 886946                  Country       $ 1.29
# 886944                  Country       $ 1.29
# 886943                  Country       $ 1.29
# 886942                  Country       $ 1.29
# 886941                  Country       $ 1.29
# 886940                  Country       $ 1.29
# 886955                  Country       $ 1.29
# 886954                  Country       $ 1.29
# 886953                  Country       $ 1.29
# 886957                  Country       $ 1.29
# 886952                  Country       $ 1.29
# 886959                  Country       $ 1.29
# 886963                  Country       $ 1.29
# 886951                  Country       $ 1.29
# 886964                  Country       $ 1.29
# 1718093  R&B , Contemporary R&B       $ 1.29
# 1551326                     Pop       $ 1.29
# 126341                      Pop       $ 0.99
# 446229                  Country       $ 1.29
# 446243                  Country       $ 1.29
# 446247                  Country       $ 1.29
# 446246                  Country       $ 1.29
# 446227                  Country       $ 1.29
# 446245                  Country       $ 1.29
# 446244                  Country       $ 1.29
# 1839704           Rap & Hip-Hop       $ 0.69
# 1652662           Rap & Hip-Hop       $ 1.29
#
#                                                                                             rtable_CopyRight  \
# _id
# 2629510                                                                     ( C ) 2014 EMI Records Nashville
# 2629654                                                                     ( C ) 2014 EMI Records Nashville
# 1300688                                                                      ( C ) 2013 The Weeknd XO , Inc.
# 812008                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 811988                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 811989                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 812010                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 811990                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 811991                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 812009                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 811986                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 812007                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 812005                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 812004                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 812006                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 1300918                                                                      ( C ) 2013 The Weeknd XO , Inc.
# 810156                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810173                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810172                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810171                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810158                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810157                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810175                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810176                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810155                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810153                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810177                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 810174                       ( C ) 2013 Hit Red Records under exclusive license to Capitol Records Nashville
# 1652441  2010 Atlantic Recording Corporation for the United States and WEA International Inc. for the wor...
# 34875                                                                        ( C ) 2014 Capitol Records Ltd.
# ...                                                                                                      ...
# 1734016                                                                   ( C ) 2010 Cash Money Records Inc.
# 886937                                                                           ( C ) 2014 La industria Inc
# 886950                                                                           ( C ) 2014 La industria Inc
# 886946                                                                           ( C ) 2014 La industria Inc
# 886944                                                                           ( C ) 2014 La industria Inc
# 886943                                                                           ( C ) 2014 La industria Inc
# 886942                                                                           ( C ) 2014 La industria Inc
# 886941                                                                           ( C ) 2014 La industria Inc
# 886940                                                                           ( C ) 2014 La industria Inc
# 886955                                                                           ( C ) 2014 La industria Inc
# 886954                                                                           ( C ) 2014 La industria Inc
# 886953                                                                           ( C ) 2014 La industria Inc
# 886957                                                                           ( C ) 2014 La industria Inc
# 886952                                                                           ( C ) 2014 La industria Inc
# 886959                                                                           ( C ) 2014 La industria Inc
# 886963                                                                           ( C ) 2014 La industria Inc
# 886951                                                                           ( C ) 2014 La industria Inc
# 886964                                                                           ( C ) 2014 La industria Inc
# 1718093                                                                   ( C ) 2011 Cash Money Records Inc.
# 1551326                                                            ( C ) 2011 The Island Def Jam Music Group
# 126341                                                                            ( C ) 2011 S-Curve Records
# 446229                                                                  ( C ) 2014 Capitol Records Nashville
# 446243                                                                  ( C ) 2014 Capitol Records Nashville
# 446247                                                                  ( C ) 2014 Capitol Records Nashville
# 446246                                                                  ( C ) 2014 Capitol Records Nashville
# 446227                                                                  ( C ) 2014 Capitol Records Nashville
# 446245                                                                  ( C ) 2014 Capitol Records Nashville
# 446244                                                                  ( C ) 2014 Capitol Records Nashville
# 1839704                                                                         ( C ) 2009 Aftermath Records
# 1652662  2010 Atlantic Recording Corporation for the United States and WEA International Inc. for the wor...
#
#         rtable_Time      rtable_Released
# _id
# 2629510        4:22   February 11 , 2014
# 2629654        4:22   February 11 , 2014
# 1300688        4:43  September 10 , 2013
# 812008         3:50  September 19 , 2011
# 811988         3:50  September 19 , 2011
# 811989         3:50  September 19 , 2011
# 812010         3:50  September 19 , 2011
# 811990         3:50  September 19 , 2011
# 811991         3:50  September 19 , 2011
# 812009         3:50  September 19 , 2011
# 811986         3:50  September 19 , 2011
# 812007         3:50  September 19 , 2011
# 812005         3:50  September 19 , 2011
# 812004         3:50  September 19 , 2011
# 812006         3:50  September 19 , 2011
# 1300918        4:43  September 10 , 2013
# 810156         3:50  September 16 , 2011
# 810173         3:50  September 16 , 2011
# 810172         3:50  September 16 , 2011
# 810171         3:50  September 16 , 2011
# 810158         3:50  September 16 , 2011
# 810157         3:50  September 16 , 2011
# 810175         3:50  September 16 , 2011
# 810176         3:50  September 16 , 2011
# 810155         3:50  September 16 , 2011
# 810153         3:50  September 16 , 2011
# 810177         3:50  September 16 , 2011
# 810174         3:50  September 16 , 2011
# 1652441        3:12   November 26 , 2010
# 34875          3:57       July 22 , 2014
# ...             ...                  ...
# 1734016        3:51   November 22 , 2010
# 886937         3:23  September 26 , 2000
# 886950         3:23  September 26 , 2000
# 886946         3:23  September 26 , 2000
# 886944         3:23  September 26 , 2000
# 886943         3:23  September 26 , 2000
# 886942         3:23  September 26 , 2000
# 886941         3:23  September 26 , 2000
# 886940         3:23  September 26 , 2000
# 886955         3:23  September 26 , 2000
# 886954         3:23  September 26 , 2000
# 886953         3:23  September 26 , 2000
# 886957         3:23  September 26 , 2000
# 886952         3:23  September 26 , 2000
# 886959         3:23  September 26 , 2000
# 886963         3:23  September 26 , 2000
# 886951         3:23  September 26 , 2000
# 886964         3:23  September 26 , 2000
# 1718093        4:36       June 21 , 2011
# 1551326        3:43    February 8 , 2011
# 126341         3:11       June 14 , 2011
# 446229         3:29     August 12 , 2014
# 446243         3:29     August 12 , 2014
# 446247         3:29     August 12 , 2014
# 446246         3:29     August 12 , 2014
# 446227         3:29     August 12 , 2014
# 446245         3:29     August 12 , 2014
# 446244         3:29     August 12 , 2014
# 1839704        0:19   December 21 , 2009
# 1652662        3:52   November 24 , 2010
#
# [5467 rows x 19 columns]

# %% [markdown]
# As you have seen, `deepmatcher` does not include a column indicating match / non-match predictions in the output table. You can easily create such a column by thresholding the `match_score` at 0.5 (which is what `deepmatcher` uses as the threshold to compute F1), or using a threshold value or your choice.

# %%
predictions['match_prediction'] = predictions['match_score'] >= 0.5

# Reorder columns to avoid scrolling...
predictions =  predictions[['match_score', 'match_prediction'] + predictions.columns.values[1:-1].tolist()]
predictions.head()
# Out:
#       match_score  match_prediction  ltable_id  rtable_id  \
# _id
# 3237     0.951813              True       2583        228
# 3274     0.328392             False       2003        229
# 3275     0.328392             False       2574        229
# 3276     0.328392             False       2575        229
# 3359     0.241110             False       2003        230
#
#                   ltable_Song_Name ltable_Artist_Name  \
# _id
# 3237  #Selfie ( Instrumental Mix )   The Chainsmokers
# 3274    #SELFIE ( Caked Up Remix )   The Chainsmokers
# 3275    #SELFIE ( Caked Up Remix )   The Chainsmokers
# 3276    #SELFIE ( Caked Up Remix )   The Chainsmokers
# 3359    #SELFIE ( Caked Up Remix )   The Chainsmokers
#
#                           ltable_Album_Name                ltable_Genre  \
# _id
# 3237  #Selfie ( Instrumental Mix ) - Single  Dance , Music , Electronic
# 3274       #SELFIE ( The Remixes ) - Single  Electronic , Music , Dance
# 3275       #SELFIE ( The Remixes ) - Single  Electronic , Music , Dance
# 3276       #SELFIE ( The Remixes ) - Single  Electronic , Music , Dance
# 3359       #SELFIE ( The Remixes ) - Single  Electronic , Music , Dance
#
#      ltable_Price  \
# _id
# 3237       $ 1.29
# 3274       $ 1.29
# 3275       $ 1.29
# 3276       $ 1.29
# 3359       $ 1.29
#
#                                                                                          ltable_CopyRight  \
# _id
# 3237  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , Inc.
# 3274  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3275  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3276  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3359  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
#
#      ltable_Time ltable_Released               rtable_Song_Name  \
# _id
# 3237        3:03       20-Mar-14   #SELFIE ( Instrumental Mix )
# 3274        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3275        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3276        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3359        3:15       17-Jun-14       #Selfie ( Botnek Remix )
#
#      rtable_Artist_Name             rtable_Album_Name  \
# _id
# 3237   The Chainsmokers  #SELFIE ( Instrumental Mix )
# 3274   The Chainsmokers       #Selfie ( The Remixes )
# 3275   The Chainsmokers       #Selfie ( The Remixes )
# 3276   The Chainsmokers       #Selfie ( The Remixes )
# 3359   The Chainsmokers       #Selfie ( The Remixes )
#
#                           rtable_Genre rtable_Price  \
# _id
# 3237                Dance & Electronic       $ 1.29
# 3274  Electronica , Dance & Electronic       $ 1.29
# 3275  Electronica , Dance & Electronic       $ 1.29
# 3276  Electronica , Dance & Electronic       $ 1.29
# 3359  Electronica , Dance & Electronic       $ 1.29
#
#                                                                                          rtable_CopyRight  \
# _id
# 3237  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3274  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3275  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3276  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3359  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
#
#      rtable_Time  rtable_Released
# _id
# 3237        3:03  March 20 , 2014
# 3274        3:52   June 17 , 2014
# 3275        3:52   June 17 , 2014
# 3276        3:52   June 17 , 2014
# 3359        3:36   June 17 , 2014

# %%
# Reset index as Magellan requires the key to be a column in the table
predictions.reset_index(inplace=True)

# %%
# Update metadata in the catalog. This information can later be used by triggers to modify the labels from 
# the learning-based matcher 
em.set_key(predictions, '_id')
em.set_fk_ltable(predictions, 'ltable_id')
em.set_fk_rtable(predictions, 'rtable_id')
em.set_ltable(predictions, A)
em.set_rtable(predictions, B)
# Out:
# True
