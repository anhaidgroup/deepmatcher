# %% [markdown]
# # Introduction

# %% [markdown]
# As a part of the ***Magellan*** ecosystem, in this tutorial we will show how to use `deepmatcher` together with `Magellan`, to perform an end-to-end Entity Matching (EM) task. Specifically, `Magellan` performs EM in a **two-stage** fashion where given two tables,
# 1. Perform **blocking** on the two tables by removing obvious non-matching tuple pairs to get a candidate set K.
# 2. Perform **matching** to predict each pair in K as match or non-match. This stage consists of the following substeps:
#     1. *Magellan* first helps the user take a sample S from K.
#     2. The user labels all pairs in S as the training data.
#     3. A classifer L will be learned on S.
#     4. The user applies L to K to predict each pair as match or non-match.
#
# Given the above workflow, `deepmatcher` fits in the step C, which is to take advantage of deep learning to learn a classifer. For the rest of the tutorial, we will use a real example, which is to match songs across two tables from iTunes and Amazon Music, to go through the workflow.
#
# For more information on `Magellan`, please go to the project website: https://sites.google.com/site/anhaidgroup/projects/magellan.

# %% [markdown]
# # Step 0. Preparation
# In order to use ***Magellan***, we need to first install it. The easiest way is to use "pip" as follow (please consult the package website for other installation options).

# %%
try:
    import py_entitymatching as em
except:
    # !pip install py_entitymatching

# %%
import deepmatcher as dm
import py_entitymatching as em

import os

# %% [markdown]
# # Step 1. Load data
# We first load the two input tables in the csv format using `Magellan`, that contain songs from iTunes and Amazon Music. These two tables are in the "example" directory included in our package.

# %%
# The path to the two input tables.
path_A = os.path.join('.', 'sample_data', 'itunes-amazon', 'tableA.csv')
path_B = os.path.join('.', 'sample_data', 'itunes-amazon', 'tableB.csv')

# %%
# Load the two tables.
A = em.read_csv_metadata(path_A, key='id')
B = em.read_csv_metadata(path_B, key='id')
# Out:
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.

# %%
# Basic information about the tables.
print('Number of tuples in A: ' + str(len(A)))
print('Number of tuples in B: ' + str(len(B)))
print('Number of tuples in A X B (i.e the cartesian product): ' + str(len(A)*len(B)))
# Out:
# Number of tuples in A: 6907
# Number of tuples in B: 55923
# Number of tuples in A X B (i.e the cartesian product): 386260161

# %%
# The first few tuples in table A.
A.head()
# Out:
#    id                            Song_Name        Artist_Name  \
# 0   0                        Runaway Train                Cam
# 1   1                             Track 14                Omi
# 2   2                       Lips Are Movin     Meghan Trainor
# 3   3  I Want a Hippopotamus for Christmas  A Great Big World
# 4   4                               Credit     Meghan Trainor
#
#                     Album_Name  \
# 0  Welcome to Cam Country - EP
# 1                       Me 4 U
# 2                        Title
# 3  I 'll Be Home For Christmas
# 4             Title ( Deluxe )
#
#                                                  Genre       Price  \
# 0  Country , Music , Contemporary Country , Honky Tonk      $ 0.99
# 1          Pop/Rock , Music , Pop , Dance , R&B / Soul  Album Only
# 2     Pop , Music , Pop/Rock , Dance , Rock , Teen Pop      $ 1.29
# 3                                      Holiday , Music      $ 1.29
# 4     Pop , Music , Rock , Pop/Rock , Dance , Teen Pop      $ 1.29
#
#                                                                                              CopyRight  \
# 0                                                                        2015 Sony Music Entertainment
# 1  2015 Ultra Records , LLC under exclusive license to Columbia Records , a Division of Sony Music ...
# 2                                    2014 , 2015 Epic Records , a division of Sony Music Entertainment
# 3                         Compilation ( P ) 2014 Epic Records , a division of Sony Music Entertainment
# 4                                    2014 , 2015 Epic Records , a division of Sony Music Entertainment
#
#    Time   Released
# 0  3:01  31-Mar-15
# 1  3:41        NaN
# 2  3:01   9-Jan-15
# 3  2:20  24-Nov-14
# 4  2:51   9-Jan-15

# %%
# The first few tuples in table B.
B.head()
# Out:
#    id                          Song_Name Artist_Name  \
# 0   0       Saxophone Stomp [ Explicit ]       Rusko
# 1   1  I Wan na Mingle [ feat . Pusher ]       Rusko
# 2   2                              Lytah       Rusko
# 3   3                       Slappy Pappy       Rusko
# 4   4                        Fushion Jam       Rusko
#
#                     Album_Name                         Genre   Price  \
# 0  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 1  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 2  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 3  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 4  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
#
#                                                                 CopyRight  \
# 0  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 1  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 2  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 3  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 4  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
#
#    Time             Released
# 0  3:20  September 16 , 2014
# 1  2:36  September 16 , 2014
# 2  3:48  September 16 , 2014
# 3  3:55  September 16 , 2014
# 4  1:48  September 16 , 2014

# %% [markdown]
# # Step 2. Block tables to get the candidate set
# We first perform blocking on A and B to get a candidate set K, by removing obvious non-matching tuple pairs. `Magellan` supports four different types of blocker: (1) attribute equivalence, (2) overlap, (3) rule-based, and (4) black-box. Typically, users need to mix and match these blockers with the debugging functionality provided in `Magellan` to get a good candidate set. (Developing a good blocker is not the focus of this tutorial. For more information on developing and debugging a blocker, please consult the user manual of `Magellan`.)
#
# Here we show an example of blocking. Observe that matching tuple pairs should have some common words in the album name, so we first create an overlap blocker on the attribute name "Album_Name" with threshold 2, to remove all pairs with word overlap less 2 in that attribute.

# %%
# Create an overlap blocker in Magellan and apply it to A and B to get the candidate set K1 which is in the format of 
# a dataframe. The "l_out_attrs" and "r_out_attrs" parameters indicate the columns that will be included in K1 from A
# and B respectively.
ob = em.OverlapBlocker()
K1 = ob.block_tables(A, B, 'Album_Name', 'Album_Name',
                    l_output_attrs=['Song_Name', 'Artist_Name', 'Album_Name', 'Genre', 'Price', 'CopyRight', 'Time', 'Released'], 
                    r_output_attrs=['Song_Name', 'Artist_Name', 'Album_Name', 'Genre', 'Price', 'CopyRight', 'Time', 'Released'],
                    overlap_size=2)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:18

# %%
# The number of tuple pairs in K1.
len(K1)
# Out:
# 3152021

# %%
# The first few tuple pairs in K1
K1.head()
# Out:
#    _id  ltable_id  rtable_id ltable_Song_Name ltable_Artist_Name  \
# 0    0       3995          0     Rudolph Blue      Brian Fechino
# 1    1       3995          1     Rudolph Blue      Brian Fechino
# 2    2       3995          2     Rudolph Blue      Brian Fechino
# 3    3       3995          3     Rudolph Blue      Brian Fechino
# 4    4       3995          4     Rudolph Blue      Brian Fechino
#
#                           ltable_Album_Name            ltable_Genre  \
# 0  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 1  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 2  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 3  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 4  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
#
#   ltable_Price ltable_CopyRight ltable_Time ltable_Released  \
# 0       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 1       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 2       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 3       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 4       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
#
#                     rtable_Song_Name rtable_Artist_Name  \
# 0       Saxophone Stomp [ Explicit ]              Rusko
# 1  I Wan na Mingle [ feat . Pusher ]              Rusko
# 2                              Lytah              Rusko
# 3                       Slappy Pappy              Rusko
# 4                        Fushion Jam              Rusko
#
#              rtable_Album_Name                  rtable_Genre rtable_Price  \
# 0  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 1  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 2  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 3  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 4  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
#
#                                                          rtable_CopyRight  \
# 0  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 1  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 2  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 3  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 4  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
#
#   rtable_Time      rtable_Released
# 0        3:20  September 16 , 2014
# 1        2:36  September 16 , 2014
# 2        3:48  September 16 , 2014
# 3        3:55  September 16 , 2014
# 4        1:48  September 16 , 2014

# %% [markdown]
# Notice that K1 has more than 3 million pair in it, which is too large to considered for matching. So we create an overlap blocking with threshold 1 on the attribute "Artist_Name" for K1, to filter all pairs in K1 that don't share any word in "Artist_Name". And we get the candidate set K2.

# %%
# Create a new overlap blocker to remove pairs from K1 that have no common word in "Artist_Name".
K2 = ob.block_candset(K1, 'Artist_Name', 'Artist_Name', overlap_size=1)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:29

# %%
# The number of tuple pairs in K2.
len(K2)
# Out:
# 167180

# %% [markdown]
# After the second blocking step, now we have a candidate set K2 with about 170K pairs. But we think it is still a bit larger to consider for matching. So we apply a third blocker, which is an overlap blocker on the attribute "Song_Name", to further reduce the size of the candidate set.

# %%
# Apply the third overlap blocker.
K3 = ob.block_candset(K2, 'Song_Name', 'Song_Name', overlap_size=1)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:01

# %%
# The number of tuples pairs in K3.
len(K3)
# Out:
# 38015

# %% [markdown]
# Now we have a candidate set with 38K pairs which is reasonable, so we take K3 as the final candidate set. We save the candidate to the disk in the csv format for future reuse.

# %%
path_K = os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial', 'candidate.csv')
K3.to_csv(path_K, index=False)

# %% [markdown]
# # Step 3. Match tuple pairs in the candidate set
# In this stage we will match tuple pairs in the candidate set to predict each of them as match or non-match. This is the part that `deepmatcher` will be involved. Specifically, it consists of the following steps:
# 1. Take a sample S from the candidate set K, and label all pairs in S.
# 2. Train a classifier L using S. Specifically, we will train a classifier using `deepmatcher`.
# 3. Apply L to the candidiate set K.

# %% [markdown]
# ## Sample and label the candidate set
# We first take a random sample S from the candidate set K using `Magellan`. Here for example, we sample 500 pairs for K. Then we label each pair as match (enter 1) or non-match (enter 0) and use S as the training data.

# %%
# Take a sample of 500 pairs from the candidate set.
S = em.sample_table(K3, 500)

# %%
# Label the sample S in a GUI. Enter 1 for match and 0 for non-match.
G = em.label_table(S, 'gold')

# %% [markdown]
# For the purposes of this tutorial, we will load in a pre-labeled dataset (of 539 tuple pairs) included in this package.

# %%
# The path to the labeled data file.
path_G = os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial', 'gold.csv')

# %%
# Load the labeled data into a dataframe.
G = em.read_csv_metadata(path_G, 
                         key='_id',
                         ltable=A, rtable=B, 
                         fk_ltable='ltable_id', fk_rtable='rtable_id')
print('Number of labeled pairs:', len(G))
# Out:
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.
# Number of labeled pairs: 539

# %% [markdown]
# ## Train a classifier using labeled data
# Once we have the labeled data, we use `deepmatcher` to train a classifier. The first thing we need to do is to split the data for training purpose. In this example, we split the labeled data into three parts: training, validation and test data, with the ratio of 3:1:1. (For now we only support spliting the labeled data into three parts train/valid/test, where the validation set is used for selecting the best model during the training epochs.) For the purpose of caching data and progressive training, we will first save the split parts to disk in the format of csv files, then load them back in. The cache file will be saved during the loading procedure. For subsequent training runs, the cache file will be used to save preprocessing time on the raw csv files, unless the csv files are modified (in this case, new cache file will be generated).

# %%
# The directory where the data splits will be saved.
split_path = os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial')

# %%
# Split labeled data into train, valid, and test csv files to disk, with the split ratio of 3:1:1.
dm.data.split(G, split_path, 'train.csv', 'valid.csv', 'test.csv',
              [3, 1, 1])

# %%
# Load the training data files from the disk. Ignore the "left_id" and "right_id" 
# columns for data preprocessing.
# The 'use_magellan_convention' parameter asks deepmatcher to use Magellan's 
# naming convention for the left and right table column name prefixes 
# ("ltable_", and "rtable_"), and also to consider "_id" as the ID column.
train, validation, test = dm.data.process(
    path=os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial'),
    cache='train_cache.pth',
    train='train.csv',
    validation='valid.csv',
    test='test.csv',
    use_magellan_convention=True,
    ignore_columns=('ltable_id', 'rtable_id'))
# Out:
# WARNING:deepmatcher.data.dataset:Rebuilding data cache because: ['One or more data files have been modified.']
#
# Reading and processing data from "./sample_data/itunes-amazon/e2e-tutorial/train.csv"
# 0% [############################# ] 100% | ETA: 00:00:00
# Reading and processing data from "./sample_data/itunes-amazon/e2e-tutorial/valid.csv"
# 0% [############################# ] 100% | ETA: 00:00:00
# Reading and processing data from "./sample_data/itunes-amazon/e2e-tutorial/test.csv"
# 0% [############################# ] 100% | ETA: 00:00:00
# Building vocabulary
# 0% [#] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
#
# Computing principal components
# 0% [#] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00

# %% [markdown]
# After we get the training data, we can use `deepmatcher` to train a classifier. Here we train a hybrid model.

# %%
# Create a hybrid model.
model = dm.MatchingModel(attr_summarizer='hybrid')

# %%
# Train the hybrid model with 10 training epochs, batch size of 16, positive-to-negative 
# ratio to be 3. We save the best model (with the 
# highest F1 score on the validation set) to 'hybrid_model.pth'.
model.run_train(
    train,
    validation,
    epochs=10,
    batch_size=16,
    best_save_path='hybrid_model.pth',
    pos_neg_ratio=3)
# Out:
# * Number of trainable parameters: 17757810
# ===>  TRAIN Epoch 1
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 1 || Run Time:    4.1 | Load Time:    0.4 || F1:  48.10 | Prec:  35.62 | Rec:  74.03 || Ex/s:  71.78
#
# ===>  EVAL Epoch 1
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 1 || Run Time:    0.6 | Load Time:    0.2 || F1:  60.71 | Prec:  58.62 | Rec:  62.96 || Ex/s: 142.70
#
# * Best F1: 60.714285714285715
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 2
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 2 || Run Time:    3.9 | Load Time:    0.4 || F1:  57.56 | Prec:  46.09 | Rec:  76.62 || Ex/s:  74.25
#
# ===>  EVAL Epoch 2
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 2 || Run Time:    0.6 | Load Time:    0.2 || F1:  63.16 | Prec:  60.00 | Rec:  66.67 || Ex/s: 140.31
#
# * Best F1: 63.15789473684211
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 3
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 3 || Run Time:    3.9 | Load Time:    0.4 || F1:  70.06 | Prec:  62.00 | Rec:  80.52 || Ex/s:  74.11
#
# ===>  EVAL Epoch 3
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 3 || Run Time:    0.6 | Load Time:    0.2 || F1:  74.58 | Prec:  68.75 | Rec:  81.48 || Ex/s: 142.42
#
# * Best F1: 74.57627118644069
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 4
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# Finished Epoch 4 || Run Time:    3.8 | Load Time:    0.4 || F1:  85.53 | Prec:  82.93 | Rec:  88.31 || Ex/s:  75.42
#
# ===>  EVAL Epoch 4
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 4 || Run Time:    0.6 | Load Time:    0.2 || F1:  67.57 | Prec:  53.19 | Rec:  92.59 || Ex/s: 142.94
#
# ---------------------
#
# ===>  TRAIN Epoch 5
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 5 || Run Time:    3.9 | Load Time:    0.4 || F1:  88.24 | Prec:  80.65 | Rec:  97.40 || Ex/s:  74.10
#
# ===>  EVAL Epoch 5
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 5 || Run Time:    0.6 | Load Time:    0.2 || F1:  73.85 | Prec:  63.16 | Rec:  88.89 || Ex/s: 143.24
#
# ---------------------
#
# ===>  TRAIN Epoch 6
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# Finished Epoch 6 || Run Time:    3.8 | Load Time:    0.4 || F1:  93.83 | Prec:  89.41 | Rec:  98.70 || Ex/s:  75.42
#
# ===>  EVAL Epoch 6
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 6 || Run Time:    0.6 | Load Time:    0.2 || F1:  76.19 | Prec:  66.67 | Rec:  88.89 || Ex/s: 143.24
#
# * Best F1: 76.1904761904762
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 7
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 7 || Run Time:    3.9 | Load Time:    0.4 || F1:  96.82 | Prec:  95.00 | Rec:  98.70 || Ex/s:  73.84
#
# ===>  EVAL Epoch 7
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 7 || Run Time:    0.6 | Load Time:    0.2 || F1:  76.92 | Prec:  65.79 | Rec:  92.59 || Ex/s: 142.57
#
# * Best F1: 76.9230769230769
# Saving best model...
# Done.
# ---------------------
#
# ===>  TRAIN Epoch 8
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 8 || Run Time:    3.9 | Load Time:    0.4 || F1:  97.44 | Prec:  96.20 | Rec:  98.70 || Ex/s:  74.04
#
# ===>  EVAL Epoch 8
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 8 || Run Time:    0.6 | Load Time:    0.2 || F1:  74.63 | Prec:  62.50 | Rec:  92.59 || Ex/s: 142.72
#
# ---------------------
#
# ===>  TRAIN Epoch 9
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 9 || Run Time:    3.9 | Load Time:    0.4 || F1:  98.06 | Prec:  97.44 | Rec:  98.70 || Ex/s:  74.92
#
# ===>  EVAL Epoch 9
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 9 || Run Time:    0.6 | Load Time:    0.2 || F1:  75.76 | Prec:  64.10 | Rec:  92.59 || Ex/s: 142.80
#
# ---------------------
#
# ===>  TRAIN Epoch 10
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 10 || Run Time:    3.9 | Load Time:    0.4 || F1:  99.35 | Prec:  98.72 | Rec: 100.00 || Ex/s:  74.25
#
# ===>  EVAL Epoch 10
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 10 || Run Time:    0.6 | Load Time:    0.2 || F1:  73.53 | Prec:  60.98 | Rec:  92.59 || Ex/s: 142.31
#
# ---------------------
#
# Loading best model...
# Training done.
# 76.9230769230769

# %% [markdown]
# Once we have the trained classifier, we can evaluate the accuracy using the test data.

# %%
# Evaluate the accuracy on the test data.
model.run_eval(test)
# Out:
# ===>  EVAL Epoch 7
# Finished Epoch 7 || Run Time:    0.3 | Load Time:    0.2 || F1:  83.08 | Prec:  72.97 | Rec:  96.43 || Ex/s: 209.82
# 83.07692307692307

# %% [markdown]
# ## Apply the trained classifier to the candidate set
# Now we have a trained classifer, we can apply it to the candidate set to predict each pair as match or non-match. To achieve this, we first load the trained model and the candidate set.

# %%
# Load the model.
model = dm.MatchingModel(attr_summarizer='hybrid')
model.load_state('hybrid_model.pth')

# %%
# Load the candidate set. Note that the trained model is an input parameter as we need to trained 
# model for candidate set preprocessing.
candidate = dm.data.process_unlabeled(
    path=os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial', 'candidate.csv'),
    trained_model=model,
    ignore_columns=('ltable_id', 'rtable_id'))
# Out:
# Reading and processing data from "./sample_data/itunes-amazon/e2e-tutorial/candidate.csv"
# 0% [##############################] 100% | ETA: 00:00:00

# %% [markdown]
# After we load the candidate set, now we make the predictions using the `run_prediction` function. The *output_attribute* argument indicates the columns that will be included in the prediction table. Here
# we use all of the columns in the candidate set.

# %%
# Predict the pairs in the candidate set and return a dataframe containing the pair id with 
# the score of being a match.
predictions = model.run_prediction(candidate, output_attributes=list(candidate.get_raw_table().columns))
# Out:
# ===>  PREDICT Epoch 7
# 0% [██████████████████████████████] 100% | ETA: 00:00:00
# Total time elapsed: 00:02:21
# Finished Epoch 7 || Run Time:   99.6 | Load Time:   41.9 || F1:   0.00 | Prec:   0.00 | Rec:   0.00 || Ex/s:   0.00

# %% [markdown]
# Below shows a few pairs in the prediction table. Note that this table is not sorted in the descending order of the
# match scores.

# %%
predictions.head()
# Out:
#       match_score  ltable_id  rtable_id              ltable_Song_Name  \
# _id
# 3237     0.831005       2583        228  #Selfie ( Instrumental Mix )
# 3238     0.404846       2003        229    #SELFIE ( Caked Up Remix )
# 3239     0.404846       2574        229    #SELFIE ( Caked Up Remix )
# 3240     0.404846       2575        229    #SELFIE ( Caked Up Remix )
# 3323     0.489662       2003        230    #SELFIE ( Caked Up Remix )
#
#      ltable_Artist_Name                      ltable_Album_Name  \
# _id
# 3237   The Chainsmokers  #Selfie ( Instrumental Mix ) - Single
# 3238   The Chainsmokers       #SELFIE ( The Remixes ) - Single
# 3239   The Chainsmokers       #SELFIE ( The Remixes ) - Single
# 3240   The Chainsmokers       #SELFIE ( The Remixes ) - Single
# 3323   The Chainsmokers       #SELFIE ( The Remixes ) - Single
#
#                     ltable_Genre ltable_Price  \
# _id
# 3237  Dance , Music , Electronic       $ 1.29
# 3238  Electronic , Music , Dance       $ 1.29
# 3239  Electronic , Music , Dance       $ 1.29
# 3240  Electronic , Music , Dance       $ 1.29
# 3323  Electronic , Music , Dance       $ 1.29
#
#                                                                                          ltable_CopyRight  \
# _id
# 3237  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , Inc.
# 3238  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3239  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3240  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3323  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
#
#      ltable_Time ltable_Released               rtable_Song_Name  \
# _id
# 3237        3:03       20-Mar-14   #SELFIE ( Instrumental Mix )
# 3238        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3239        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3240        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3323        3:15       17-Jun-14       #Selfie ( Botnek Remix )
#
#      rtable_Artist_Name             rtable_Album_Name  \
# _id
# 3237   The Chainsmokers  #SELFIE ( Instrumental Mix )
# 3238   The Chainsmokers       #Selfie ( The Remixes )
# 3239   The Chainsmokers       #Selfie ( The Remixes )
# 3240   The Chainsmokers       #Selfie ( The Remixes )
# 3323   The Chainsmokers       #Selfie ( The Remixes )
#
#                           rtable_Genre rtable_Price  \
# _id
# 3237                Dance & Electronic       $ 1.29
# 3238  Electronica , Dance & Electronic       $ 1.29
# 3239  Electronica , Dance & Electronic       $ 1.29
# 3240  Electronica , Dance & Electronic       $ 1.29
# 3323  Electronica , Dance & Electronic       $ 1.29
#
#                                                                                          rtable_CopyRight  \
# _id
# 3237  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3238  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3239  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3240  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3323  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
#
#      rtable_Time  rtable_Released
# _id
# 3237        3:03  March 20 , 2014
# 3238        3:52   June 17 , 2014
# 3239        3:52   June 17 , 2014
# 3240        3:52   June 17 , 2014
# 3323        3:36   June 17 , 2014

# %% [markdown]
# We can simply manipulate the prediction table above to get the pairs that we want. Suppose we are only interested in pairs with the match score more over 0.9, and we want to display them sorting in the descending order on match score. This can be achieved as follow.

# %%
high_score_pairs = predictions[predictions['match_score'] >= 0.9].sort_values(by=['match_score'], ascending=False)
high_score_pairs
# Out:
#          match_score  ltable_id  rtable_id  \
# _id
# 2629510     0.998077       5481      48789
# 2629654     0.998077       5481      48801
# 609582      0.997912       3895      16397
# 609584      0.997912       3902      16397
# 609576      0.997912       3886      16397
# 609579      0.997912       3891      16397
# 609580      0.997912       3892      16397
# 609583      0.997906       3900      16397
# 609577      0.997906       3887      16397
# 609578      0.997906       3889      16397
# 609581      0.997906       3893      16397
# 1046836     0.997770       4350      23361
# 1046839     0.997770       4373      23361
# 1046838     0.997770       4358      23361
# 1046837     0.997770       4357      23361
# 1046840     0.997770       4374      23361
# 1046844     0.997770       4395      23361
# 1046841     0.997770       4375      23361
# 1046835     0.997770       4347      23361
# 1046834     0.997770       4326      23361
# 1046842     0.997770       4384      23361
# 1046843     0.997770       4394      23361
# 1572056     0.997589        418      33368
# 1572045     0.997589        401      33368
# 1572049     0.997589        405      33368
# 1572052     0.997589        409      33368
# 1572054     0.997589        416      33368
# 1572055     0.997589        417      33368
# 1572044     0.997589        400      33368
# 1572036     0.997589        388      33368
# ...              ...        ...        ...
# 1652660     0.902099       5683      35069
# 2203917     0.901796       5923      45228
# 1316439     0.901549       5217      27226
# 2802140     0.901531       1523      50060
# 2708469     0.901395       1670      49479
# 2708467     0.901395       1661      49479
# 2708466     0.901395       1658      49479
# 2708465     0.901395       1655      49479
# 2708468     0.901395       1666      49479
# 2754947     0.901332        999      49701
# 2754946     0.901332        998      49701
# 2754945     0.901332        997      49701
# 2754944     0.901332        996      49701
# 2754943     0.901332        995      49701
# 2754942     0.901332        950      49701
# 1487981     0.901259       6430      31089
# 1255287     0.901125        421      25450
# 1173783     0.900801        697      24617
# 1173784     0.900801        698      24617
# 1173785     0.900801        699      24617
# 1173786     0.900801        700      24617
# 1173787     0.900801        701      24617
# 2023743     0.900741       4445      42470
# 1652525     0.900661       5686      35063
# 405803      0.900383       5525       9835
# 825156      0.900361       5886      19154
# 2024361     0.900352       1426      42520
# 245446      0.900299       5625       6534
# 2415157     0.900175       4639      47319
# 2877861     0.900015       5717      50847
#
#                                                                        ltable_Song_Name  \
# _id
# 2629510                                                                       Talladega
# 2629654                                                                       Talladega
# 609582                                                                             X2CU
# 609584                                                                             X2CU
# 609576                                                                             X2CU
# 609579                                                                             X2CU
# 609580                                                                             X2CU
# 609583                                                                             X2CU
# 609577                                                                             X2CU
# 609578                                                                             X2CU
# 609581                                                                             X2CU
# 1046836                                                                      Tackle Box
# 1046839                                                                      Tackle Box
# 1046838                                                                      Tackle Box
# 1046837                                                                      Tackle Box
# 1046840                                                                      Tackle Box
# 1046844                                                                      Tackle Box
# 1046841                                                                      Tackle Box
# 1046835                                                                      Tackle Box
# 1046834                                                                      Tackle Box
# 1046842                                                                      Tackle Box
# 1046843                                                                      Tackle Box
# 1572056                                                         Nothing Would Be Better
# 1572045                                                         Nothing Would Be Better
# 1572049                                                         Nothing Would Be Better
# 1572052                                                         Nothing Would Be Better
# 1572054                                                         Nothing Would Be Better
# 1572055                                                         Nothing Would Be Better
# 1572044                                                         Nothing Would Be Better
# 1572036                                                         Nothing Would Be Better
# ...                                                                                 ...
# 1652660                                                       21 ( feat . Laza Morgan )
# 2203917                                                 Powerless ( Say What You Want )
# 1316439                                         Ass On the Floor ( feat . Swizz Beatz )
# 2802140                   I 'll Follow You ( From the Warner Sound Live Room Sessions )
# 2708469                                                      Son of Sam ( Bonus Track )
# 2708467                                                      Son of Sam ( Bonus Track )
# 2708466                                                      Son of Sam ( Bonus Track )
# 2708465                                                      Son of Sam ( Bonus Track )
# 2708468                                                      Son of Sam ( Bonus Track )
# 2754947                                                                 White Christmas
# 2754946                                                                 White Christmas
# 2754945                                                                 White Christmas
# 2754944                                                                 White Christmas
# 2754943                                                                 White Christmas
# 2754942                                                                 White Christmas
# 1487981                                                               Little White Lies
# 1255287                                               Jealous ( Bent Collective Remix )
# 1173783                                       Thriller ( Live From Hammersmith Palais )
# 1173784                                       Thriller ( Live From Hammersmith Palais )
# 1173785                                       Thriller ( Live From Hammersmith Palais )
# 1173786                                       Thriller ( Live From Hammersmith Palais )
# 1173787                                       Thriller ( Live From Hammersmith Palais )
# 2023743                         Steal My Girl ( Big Payno & Afterhrs Pool Party Remix )
# 1652525                 Why You Up In Here ( feat . Ludacris , Git Fresh & Gucci Mane )
# 405803                                            Pledge Allegiance to the Hag ( Live )
# 825156                                                                      All for You
# 2024361                                          Stole the Show ( feat . Parson James )
# 245446   I 'm Like a Lawyer With the Way I 'm Always Trying to Get You Off ( Me & You )
# 2415157                                                                    The Stranger
# 2877861                                                                      Do n't Cry
#
#                         ltable_Artist_Name  \
# _id
# 2629510                        Eric Church
# 2629654                        Eric Church
# 609582                        Jason Derulo
# 609584                        Jason Derulo
# 609576                        Jason Derulo
# 609579                        Jason Derulo
# 609580                        Jason Derulo
# 609583                        Jason Derulo
# 609577                        Jason Derulo
# 609578                        Jason Derulo
# 609581                        Jason Derulo
# 1046836                         Luke Bryan
# 1046839                         Luke Bryan
# 1046838                         Luke Bryan
# 1046837                         Luke Bryan
# 1046840                         Luke Bryan
# 1046844                         Luke Bryan
# 1046841                         Luke Bryan
# 1046835                         Luke Bryan
# 1046834                         Luke Bryan
# 1046842                         Luke Bryan
# 1046843                         Luke Bryan
# 1572056                         Nick Jonas
# 1572045                         Nick Jonas
# 1572049                         Nick Jonas
# 1572052                         Nick Jonas
# 1572054                         Nick Jonas
# 1572055                         Nick Jonas
# 1572044                         Nick Jonas
# 1572036                         Nick Jonas
# ...                                    ...
# 1652660                           Flo Rida
# 2203917                      Nelly Furtado
# 1316439  Diddy - Dirty Money & Swizz Beatz
# 2802140                          Shinedown
# 2708469                          Shinedown
# 2708467                          Shinedown
# 2708466                          Shinedown
# 2708465                          Shinedown
# 2708468                          Shinedown
# 2754947                       Taylor Swift
# 2754946                       Taylor Swift
# 2754945                       Taylor Swift
# 2754944                       Taylor Swift
# 2754943                       Taylor Swift
# 2754942                       Taylor Swift
# 1487981                      One Direction
# 1255287                         Nick Jonas
# 1173783                       Fall Out Boy
# 1173784                       Fall Out Boy
# 1173785                       Fall Out Boy
# 1173786                       Fall Out Boy
# 1173787                       Fall Out Boy
# 2023743                      One Direction
# 1652525                           Flo Rida
# 405803                         Eric Church
# 825156                         Keith Urban
# 2024361                               Kygo
# 245446                        Fall Out Boy
# 2415157    B ' © la Fleck & The Flecktones
# 2877861                       Kevin Rudolf
#
#                                                               ltable_Album_Name  \
# _id
# 2629510                                                           The Outsiders
# 2629654                                                           The Outsiders
# 609582                                                          Everything Is 4
# 609584                                                          Everything Is 4
# 609576                                                          Everything Is 4
# 609579                                                          Everything Is 4
# 609580                                                          Everything Is 4
# 609583                                                          Everything Is 4
# 609577                                                          Everything Is 4
# 609578                                                          Everything Is 4
# 609581                                                          Everything Is 4
# 1046836                                                           I 'll Stay Me
# 1046839                                                           I 'll Stay Me
# 1046838                                                           I 'll Stay Me
# 1046837                                                           I 'll Stay Me
# 1046840                                                           I 'll Stay Me
# 1046844                                                           I 'll Stay Me
# 1046841                                                           I 'll Stay Me
# 1046835                                                           I 'll Stay Me
# 1046834                                                           I 'll Stay Me
# 1046842                                                           I 'll Stay Me
# 1046843                                                           I 'll Stay Me
# 1572056                                                              Nick Jonas
# 1572045                                                              Nick Jonas
# 1572049                                                              Nick Jonas
# 1572052                                                              Nick Jonas
# 1572054                                                              Nick Jonas
# 1572055                                                              Nick Jonas
# 1572044                                                              Nick Jonas
# 1572036                                                              Nick Jonas
# ...                                                                         ...
# 1652660                                 Only One Flo , Pt. 1 ( Deluxe Version )
# 2203917                            The Best of Nelly Furtado ( Deluxe Version )
# 1316439                                                     Last Train to Paris
# 2802140  I 'll Follow You ( From the Warner Sound Live Room Sessions ) - Single
# 2708469                                 The Sound of Madness ( Deluxe Version )
# 2708467                                 The Sound of Madness ( Deluxe Version )
# 2708466                                 The Sound of Madness ( Deluxe Version )
# 2708465                                 The Sound of Madness ( Deluxe Version )
# 2708468                                 The Sound of Madness ( Deluxe Version )
# 2754947                                The Taylor Swift Holiday Collection - EP
# 2754946                                The Taylor Swift Holiday Collection - EP
# 2754945                                The Taylor Swift Holiday Collection - EP
# 2754944                                The Taylor Swift Holiday Collection - EP
# 2754943                                The Taylor Swift Holiday Collection - EP
# 2754942                                The Taylor Swift Holiday Collection - EP
# 1487981                                    Midnight Memories ( Deluxe Edition )
# 1255287                              Jealous ( Bent Collective Remix ) - Single
# 1173783                                    Infinity On High - Deluxe Bonus - EP
# 1173784                                    Infinity On High - Deluxe Bonus - EP
# 1173785                                    Infinity On High - Deluxe Bonus - EP
# 1173786                                    Infinity On High - Deluxe Bonus - EP
# 1173787                                    Infinity On High - Deluxe Bonus - EP
# 2023743        Steal My Girl ( Big Payno & Afterhrs Pool Party Remix ) - Single
# 1652525                                 Only One Flo , Pt. 1 ( Deluxe Version )
# 405803                                               Caught In the Act ( Live )
# 825156                                            Get Closer ( Deluxe Version )
# 2024361                         Stole the Show ( feat . Parson James ) - Single
# 245446              Believers Never Die - Greatest Hits ( Bonus Track Version )
# 2415157                          Twang ! A Tribute to Hank Marvin & The Shadows
# 2877861                                                              To the Sky
#
#                                                                                                 ltable_Genre  \
# _id
# 2629510                                                Country , Music , Contemporary Country , Urban Cowboy
# 2629654                                                Country , Music , Contemporary Country , Urban Cowboy
# 609582                                            Pop , Music , Rock , R&B / Soul , Contemporary R&B , Dance
# 609584                                            Pop , Music , Rock , R&B / Soul , Contemporary R&B , Dance
# 609576                                            Pop , Music , Rock , R&B / Soul , Contemporary R&B , Dance
# 609579                                            Pop , Music , Rock , R&B / Soul , Contemporary R&B , Dance
# 609580                                            Pop , Music , Rock , R&B / Soul , Contemporary R&B , Dance
# 609583                                            Pop , Music , Rock , Dance , R&B / Soul , Contemporary R&B
# 609577                                            Pop , Music , Rock , Dance , R&B / Soul , Contemporary R&B
# 609578                                            Pop , Music , Rock , Dance , R&B / Soul , Contemporary R&B
# 609581                                            Pop , Music , Rock , Dance , R&B / Soul , Contemporary R&B
# 1046836                                                         Country , Music , Contemporary Country , Pop
# 1046839                                                         Country , Music , Contemporary Country , Pop
# 1046838                                                         Country , Music , Contemporary Country , Pop
# 1046837                                                         Country , Music , Contemporary Country , Pop
# 1046840                                                         Country , Music , Contemporary Country , Pop
# 1046844                                                         Country , Music , Contemporary Country , Pop
# 1046841                                                         Country , Music , Contemporary Country , Pop
# 1046835                                                         Country , Music , Contemporary Country , Pop
# 1046834                                                         Country , Music , Contemporary Country , Pop
# 1046842                                                         Country , Music , Contemporary Country , Pop
# 1046843                                                         Country , Music , Contemporary Country , Pop
# 1572056                               Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1572045                               Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1572049                               Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1572052                               Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1572054                               Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1572055                               Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1572044                               Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1572036                               Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# ...                                                                                                      ...
# 1652660                                                              Hip-Hop/Rap , Music , Rap , Dirty South
# 2203917  Pop , Music , Rock , Vocal , Adult Alternative , Singer/Songwriter , Contemporary Singer/Songwriter
# 1316439                                    Hip-Hop/Rap , Music , R&B / Soul , Contemporary R&B , Dance , Rap
# 2802140                                                                                         Rock , Music
# 2708469                                              Rock , Music , Metal , Alternative , Grunge , Hard Rock
# 2708467                                              Rock , Music , Metal , Alternative , Grunge , Hard Rock
# 2708466                                              Rock , Music , Metal , Alternative , Grunge , Hard Rock
# 2708465                                              Rock , Music , Metal , Alternative , Grunge , Hard Rock
# 2708468                                              Rock , Music , Metal , Alternative , Grunge , Hard Rock
# 2754947                                                   Holiday , Music , Country , Honky Tonk , Christmas
# 2754946                                                   Holiday , Music , Country , Honky Tonk , Christmas
# 2754945                                                   Holiday , Music , Country , Honky Tonk , Christmas
# 2754944                                                   Holiday , Music , Country , Honky Tonk , Christmas
# 2754943                                                   Holiday , Music , Country , Honky Tonk , Christmas
# 2754942                                                   Holiday , Music , Country , Honky Tonk , Christmas
# 1487981                                                     Pop , Music , Rock , Teen Pop , Pop/Rock , Dance
# 1255287                                                                    Dance , Music , Rock , R&B / Soul
# 1173783                                                Alternative , Music , Punk , Rock , Adult Alternative
# 1173784                                                Alternative , Music , Punk , Rock , Adult Alternative
# 1173785                                                Alternative , Music , Punk , Rock , Adult Alternative
# 1173786                                                Alternative , Music , Punk , Rock , Adult Alternative
# 1173787                                                Alternative , Music , Punk , Rock , Adult Alternative
# 2023743                                                                                          Pop , Music
# 1652525                                                              Hip-Hop/Rap , Music , Rap , Dirty South
# 405803                                                 Country , Music , Contemporary Country , Urban Cowboy
# 825156                           Country , Music , Honky Tonk , Pop , Pop/Rock , Contemporary Country , Rock
# 2024361                                                                           Dance , Music , Electronic
# 245446                                                 Alternative , Music , Rock , Adult Alternative , Punk
# 2415157                                                                         Tribute , Music , Pop , Rock
# 2877861                                        Pop,Music,Hip-Hop / Rap , Rap , R&B / Soul , Rock , Hard Rock
#
#         ltable_Price  \
# _id
# 2629510       $ 1.29
# 2629654       $ 1.29
# 609582        $ 1.29
# 609584        $ 1.29
# 609576        $ 1.29
# 609579        $ 1.29
# 609580        $ 1.29
# 609583        $ 1.29
# 609577        $ 1.29
# 609578        $ 1.29
# 609581        $ 1.29
# 1046836       $ 1.29
# 1046839       $ 1.29
# 1046838       $ 1.29
# 1046837       $ 1.29
# 1046840       $ 1.29
# 1046844       $ 1.29
# 1046841       $ 1.29
# 1046835       $ 1.29
# 1046834       $ 1.29
# 1046842       $ 1.29
# 1046843       $ 1.29
# 1572056       $ 1.29
# 1572045       $ 1.29
# 1572049       $ 1.29
# 1572052       $ 1.29
# 1572054       $ 1.29
# 1572055       $ 1.29
# 1572044       $ 1.29
# 1572036       $ 1.29
# ...              ...
# 1652660       $ 1.29
# 2203917       $ 1.29
# 1316439       $ 1.29
# 2802140       $ 1.29
# 2708469   Album Only
# 2708467   Album Only
# 2708466   Album Only
# 2708465   Album Only
# 2708468   Album Only
# 2754947       $ 1.29
# 2754946       $ 1.29
# 2754945       $ 1.29
# 2754944       $ 1.29
# 2754943       $ 1.29
# 2754942       $ 1.29
# 1487981       $ 1.29
# 1255287       $ 1.29
# 1173783       $ 0.99
# 1173784       $ 0.99
# 1173785       $ 0.99
# 1173786       $ 0.99
# 1173787       $ 0.99
# 2023743       $ 1.29
# 1652525       $ 1.29
# 405803        $ 1.29
# 825156        $ 1.29
# 2024361       $ 1.29
# 245446        $ 1.29
# 2415157       $ 0.99
# 2877861       $ 0.99
#
#                                                                                             ltable_CopyRight  \
# _id
# 2629510                                                                      ‰ ãÑ 2013 EMI Records Nashville
# 2629654                                                                      ‰ ãÑ 2013 EMI Records Nashville
# 609582                                                                      2015 Warner Bros. . Records Inc.
# 609584                                                                      2015 Warner Bros. . Records Inc.
# 609576                                                                      2015 Warner Bros. . Records Inc.
# 609579                                                                      2015 Warner Bros. . Records Inc.
# 609580                                                                      2015 Warner Bros. . Records Inc.
# 609583                                                                      2015 Warner Bros. . Records Inc.
# 609577                                                                      2015 Warner Bros. . Records Inc.
# 609578                                                                      2015 Warner Bros. . Records Inc.
# 609581                                                                      2015 Warner Bros. . Records Inc.
# 1046836  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1046839  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1046838  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1046837  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1046840  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1046844  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1046841  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1046835  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1046834  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1046842  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1046843  2006 , 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a vio...
# 1572056                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1572045                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1572049                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1572052                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1572054                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1572055                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1572044                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1572036                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# ...                                                                                                      ...
# 1652660  ‰ ãÑ 2010 Atlantic Recording Corporation for the United States and WEA International Inc. for th...
# 2203917                                                                             ‰ ãÑ 2010 Geffen Records
# 1316439                                                                 ‰ ãÑ 2010 Bad Boy/Interscope Records
# 2802140  2013 Atlantic Recording Corporation for the United States and WEA International Inc. for the wor...
# 2708469  2008 Atlantic Recording Corp. for the United States and WEA International Inc. for the world out...
# 2708467  2008 Atlantic Recording Corp. for the United States and WEA International Inc. for the world out...
# 2708466  2008 Atlantic Recording Corp. for the United States and WEA International Inc. for the world out...
# 2708465  2008 Atlantic Recording Corp. for the United States and WEA International Inc. for the world out...
# 2708468  2008 Atlantic Recording Corp. for the United States and WEA International Inc. for the world out...
# 2754947                                                                       2008 Big Machine Records , LLC
# 2754946                                                                       2008 Big Machine Records , LLC
# 2754945                                                                       2008 Big Machine Records , LLC
# 2754944                                                                       2008 Big Machine Records , LLC
# 2754943                                                                       2008 Big Machine Records , LLC
# 2754942                                                                       2008 Big Machine Records , LLC
# 1487981               ‰ ãÑ 2013 Simco Limited under exclusive license to Sony Music Entertainment UK Limited
# 1255287                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1173783                                                                  2007 The Island Def Jam Music Group
# 1173784                                                                  2007 The Island Def Jam Music Group
# 1173785                                                                  2007 The Island Def Jam Music Group
# 1173786                                                                  2007 The Island Def Jam Music Group
# 1173787                                                                  2007 The Island Def Jam Music Group
# 2023743                    2014 Simco Limited under exclusive license to Sony Music Entertainment UK Limited
# 1652525  ‰ ãÑ 2010 Atlantic Recording Corporation for the United States and WEA International Inc. for th...
# 405803   ‰ ãÑ 2013 EMI Records Nashville . All rights reserved . Unauthorized reproduction is a violation...
# 825156   ‰ ãÑ 2010 Hit Red Records under exclusive license to Capitol Records Nashville . All rights rese...
# 2024361  2015 Kygo under exclusive license to Sony Music Entertainment International Ltd / Ultra Records ...
# 245446                                                              ‰ ãÑ 2009 The Island Def Jam Music Group
# 2415157                                                                                  1996 Ark 21 Records
# 2877861                                                                    ‰ ãÑ 2010 Cash Money Records Inc.
#
#         ltable_Time ltable_Released  \
# _id
# 2629510        4:22       11-Feb-14
# 2629654        4:22       11-Feb-14
# 609582         5:13        1-Jun-15
# 609584         5:13        1-Jun-15
# 609576         5:13        1-Jun-15
# 609579         5:13        1-Jun-15
# 609580         5:13        1-Jun-15
# 609583         5:13       29-May-15
# 609577         5:13       29-May-15
# 609578         5:13       29-May-15
# 609581         5:13       29-May-15
# 1046836        4:02       14-Aug-07
# 1046839        4:02       14-Aug-07
# 1046838        4:02       14-Aug-07
# 1046837        4:02       14-Aug-07
# 1046840        4:02       14-Aug-07
# 1046844        4:02       14-Aug-07
# 1046841        4:02       14-Aug-07
# 1046835        4:02       14-Aug-07
# 1046834        4:02       14-Aug-07
# 1046842        4:02       14-Aug-07
# 1046843        4:02       14-Aug-07
# 1572056        4:34       10-Nov-14
# 1572045        4:34       10-Nov-14
# 1572049        4:34       10-Nov-14
# 1572052        4:34       10-Nov-14
# 1572054        4:34       10-Nov-14
# 1572055        4:34       10-Nov-14
# 1572044        4:34       10-Nov-14
# 1572036        4:34       10-Nov-14
# ...             ...             ...
# 1652660        3:52       26-Nov-10
# 2203917        3:54       16-Nov-10
# 1316439        4:04       14-Dec-10
# 2802140        4:02       16-Apr-13
# 2708469        3:37       23-Jun-08
# 2708467        3:37       23-Jun-08
# 2708466        3:37       23-Jun-08
# 2708465        3:37       23-Jun-08
# 2708468        3:37       23-Jun-08
# 2754947        2:34       14-Oct-07
# 2754946        2:34       14-Oct-07
# 2754945        2:34       14-Oct-07
# 2754944        2:34       14-Oct-07
# 2754943        2:34       14-Oct-07
# 2754942        2:34       14-Oct-07
# 1487981        3:17       25-Nov-13
# 1255287        7:02       27-Oct-14
# 1173783        3:32       20-Nov-07
# 1173784        3:32       20-Nov-07
# 1173785        3:32       20-Nov-07
# 1173786        3:32       20-Nov-07
# 1173787        3:32       20-Nov-07
# 2023743        5:20       20-Oct-14
# 1652525        3:36       26-Nov-10
# 405803         4:55        5-Apr-13
# 825156         3:37       22-Feb-11
# 2024361        3:42       23-Mar-15
# 245446         3:35       17-Nov-09
# 2415157        3:47        1-Jan-96
# 2877861        2:51       15-Jun-10
#
#                                                           rtable_Song_Name  \
# _id
# 2629510                                                          Talladega
# 2629654                                                          Talladega
# 609582                                                                X2CU
# 609584                                                                X2CU
# 609576                                                                X2CU
# 609579                                                                X2CU
# 609580                                                                X2CU
# 609583                                                                X2CU
# 609577                                                                X2CU
# 609578                                                                X2CU
# 609581                                                                X2CU
# 1046836                                                         Tackle Box
# 1046839                                                         Tackle Box
# 1046838                                                         Tackle Box
# 1046837                                                         Tackle Box
# 1046840                                                         Tackle Box
# 1046844                                                         Tackle Box
# 1046841                                                         Tackle Box
# 1046835                                                         Tackle Box
# 1046834                                                         Tackle Box
# 1046842                                                         Tackle Box
# 1046843                                                         Tackle Box
# 1572056                                            Nothing Would Be Better
# 1572045                                            Nothing Would Be Better
# 1572049                                            Nothing Would Be Better
# 1572052                                            Nothing Would Be Better
# 1572054                                            Nothing Would Be Better
# 1572055                                            Nothing Would Be Better
# 1572044                                            Nothing Would Be Better
# 1572036                                            Nothing Would Be Better
# ...                                                                    ...
# 1652660                                          21 ( Feat . Laza Morgan )
# 2203917                                    Powerless ( Say What You Want )
# 1316439                 A ** On The Floor [ feat . Swizz Beatz ] [ Clean ]
# 2802140                                            Bully ( The Live Room )
# 2708469                                         Son Of Sam ( Bonus Track )
# 2708467                                         Son Of Sam ( Bonus Track )
# 2708466                                         Son Of Sam ( Bonus Track )
# 2708465                                         Son Of Sam ( Bonus Track )
# 2708468                                         Son Of Sam ( Bonus Track )
# 2754947                                   Christmas Must Be Something More
# 2754946                                   Christmas Must Be Something More
# 2754945                                   Christmas Must Be Something More
# 2754944                                   Christmas Must Be Something More
# 2754943                                   Christmas Must Be Something More
# 2754942                                   Christmas Must Be Something More
# 1487981                                                  Little White Lies
# 1255287                                  Jealous ( Bent Collective Remix )
# 1173783                          Thriller ( Live From Hammersmith Palais )
# 1173784                          Thriller ( Live From Hammersmith Palais )
# 1173785                          Thriller ( Live From Hammersmith Palais )
# 1173786                          Thriller ( Live From Hammersmith Palais )
# 1173787                          Thriller ( Live From Hammersmith Palais )
# 2023743            Steal My Girl ( Big Payno & Afterhrs Pool Party Remix )
# 1652525  Why You Up In Here ( Feat . Ludacris , Git Fresh And Gucci Mane )
# 405803                               Pledge Allegiance To The Hag ( Live )
# 825156                                                         Without You
# 2024361                                                     Stole the Show
# 245446                                     The Take Over , The Breaks Over
# 2415157                                                        The Fighter
# 2877861                                                         Do n't Cry
#
#                rtable_Artist_Name  \
# _id
# 2629510               Eric Church
# 2629654               Eric Church
# 609582               Jason Derulo
# 609584               Jason Derulo
# 609576               Jason Derulo
# 609579               Jason Derulo
# 609580               Jason Derulo
# 609583               Jason Derulo
# 609577               Jason Derulo
# 609578               Jason Derulo
# 609581               Jason Derulo
# 1046836                Luke Bryan
# 1046839                Luke Bryan
# 1046838                Luke Bryan
# 1046837                Luke Bryan
# 1046840                Luke Bryan
# 1046844                Luke Bryan
# 1046841                Luke Bryan
# 1046835                Luke Bryan
# 1046834                Luke Bryan
# 1046842                Luke Bryan
# 1046843                Luke Bryan
# 1572056                Nick Jonas
# 1572045                Nick Jonas
# 1572049                Nick Jonas
# 1572052                Nick Jonas
# 1572054                Nick Jonas
# 1572055                Nick Jonas
# 1572044                Nick Jonas
# 1572036                Nick Jonas
# ...                           ...
# 1652660                  Flo Rida
# 2203917             Nelly Furtado
# 1316439       Diddy - Dirty Money
# 2802140                 Shinedown
# 2708469                 Shinedown
# 2708467                 Shinedown
# 2708466                 Shinedown
# 2708465                 Shinedown
# 2708468                 Shinedown
# 2754947              Taylor Swift
# 2754946              Taylor Swift
# 2754945              Taylor Swift
# 2754944              Taylor Swift
# 2754943              Taylor Swift
# 2754942              Taylor Swift
# 1487981             One Direction
# 1255287                Nick Jonas
# 1173783              Fall Out Boy
# 1173784              Fall Out Boy
# 1173785              Fall Out Boy
# 1173786              Fall Out Boy
# 1173787              Fall Out Boy
# 2023743             One Direction
# 1652525                  Flo Rida
# 405803                Eric Church
# 825156                Keith Urban
# 2024361  Kygo feat . Parson James
# 245446               Fall Out Boy
# 2415157            The Dream Team
# 2877861              Kevin Rudolf
#
#                                                                    rtable_Album_Name  \
# _id
# 2629510                                                                The Outsiders
# 2629654                                                                The Outsiders
# 609582                                                     Everything Is 4 [ Clean ]
# 609584                                                     Everything Is 4 [ Clean ]
# 609576                                                     Everything Is 4 [ Clean ]
# 609579                                                     Everything Is 4 [ Clean ]
# 609580                                                     Everything Is 4 [ Clean ]
# 609583                                                     Everything Is 4 [ Clean ]
# 609577                                                     Everything Is 4 [ Clean ]
# 609578                                                     Everything Is 4 [ Clean ]
# 609581                                                     Everything Is 4 [ Clean ]
# 1046836                                                                I 'll Stay Me
# 1046839                                                                I 'll Stay Me
# 1046838                                                                I 'll Stay Me
# 1046837                                                                I 'll Stay Me
# 1046840                                                                I 'll Stay Me
# 1046844                                                                I 'll Stay Me
# 1046841                                                                I 'll Stay Me
# 1046835                                                                I 'll Stay Me
# 1046834                                                                I 'll Stay Me
# 1046842                                                                I 'll Stay Me
# 1046843                                                                I 'll Stay Me
# 1572056                                                      Nick Jonas [ Explicit ]
# 1572045                                                      Nick Jonas [ Explicit ]
# 1572049                                                      Nick Jonas [ Explicit ]
# 1572052                                                      Nick Jonas [ Explicit ]
# 1572054                                                      Nick Jonas [ Explicit ]
# 1572055                                                      Nick Jonas [ Explicit ]
# 1572044                                                      Nick Jonas [ Explicit ]
# 1572036                                                      Nick Jonas [ Explicit ]
# ...                                                                              ...
# 1652660                                                      Only One Flo ( Part 1 )
# 2203917                              The Best of Nelly Furtado [ + Digital Booklet ]
# 1316439                                       Last Train To Paris ( Deluxe Version )
# 2802140                                                The Warner Sound Live Room EP
# 2708469                                 The Sound Of Madness [ Explicit ] [ Deluxe ]
# 2708467                                 The Sound Of Madness [ Explicit ] [ Deluxe ]
# 2708466                                 The Sound Of Madness [ Explicit ] [ Deluxe ]
# 2708465                                 The Sound Of Madness [ Explicit ] [ Deluxe ]
# 2708468                                 The Sound Of Madness [ Explicit ] [ Deluxe ]
# 2754947                                          The Taylor Swift Holiday Collection
# 2754946                                          The Taylor Swift Holiday Collection
# 2754945                                          The Taylor Swift Holiday Collection
# 2754944                                          The Taylor Swift Holiday Collection
# 2754943                                          The Taylor Swift Holiday Collection
# 2754942                                          The Taylor Swift Holiday Collection
# 1487981                                                 Midnight Memories ( Deluxe )
# 1255287                                            Jealous ( Bent Collective Remix )
# 1173783                                          Infinity On High ( Deluxe Version )
# 1173784                                          Infinity On High ( Deluxe Version )
# 1173785                                          Infinity On High ( Deluxe Version )
# 1173786                                          Infinity On High ( Deluxe Version )
# 1173787                                          Infinity On High ( Deluxe Version )
# 2023743                      Steal My Girl ( Big Payno & Afterhrs Pool Party Remix )
# 1652525         Only One Flo ( Part 1 ) [ Deluxe ] [ + Video ] [ + Digital Booklet ]
# 405803                                                      Caught In The Act : Live
# 825156                                                 Get Closer ( Deluxe Version )
# 2024361                                                               Stole the Show
# 245446                                           Believers Never Die - Greatest Hits
# 2415157  The Fighter ( Gym Class Heroes feat . Ryan Tedder Special Edition Tribute )
# 2877861                                                                   To The Sky
#
#                                      rtable_Genre rtable_Price  \
# _id
# 2629510                                   Country       $ 1.29
# 2629654                                   Country       $ 1.29
# 609582                                        Pop       $ 1.29
# 609584                                        Pop       $ 1.29
# 609576                                        Pop       $ 1.29
# 609579                                        Pop       $ 1.29
# 609580                                        Pop       $ 1.29
# 609583                                        Pop       $ 1.29
# 609577                                        Pop       $ 1.29
# 609578                                        Pop       $ 1.29
# 609581                                        Pop       $ 1.29
# 1046836                                   Country       $ 1.29
# 1046839                                   Country       $ 1.29
# 1046838                                   Country       $ 1.29
# 1046837                                   Country       $ 1.29
# 1046840                                   Country       $ 1.29
# 1046844                                   Country       $ 1.29
# 1046841                                   Country       $ 1.29
# 1046835                                   Country       $ 1.29
# 1046834                                   Country       $ 1.29
# 1046842                                   Country       $ 1.29
# 1046843                                   Country       $ 1.29
# 1572056                                       Pop       $ 1.29
# 1572045                                       Pop       $ 1.29
# 1572049                                       Pop       $ 1.29
# 1572052                                       Pop       $ 1.29
# 1572054                                       Pop       $ 1.29
# 1572055                                       Pop       $ 1.29
# 1572044                                       Pop       $ 1.29
# 1572036                                       Pop       $ 1.29
# ...                                           ...          ...
# 1652660                             Rap & Hip-Hop       $ 1.29
# 2203917                                       Pop       $ 1.29
# 1316439                             Rap & Hip-Hop       $ 1.29
# 2802140                                      Rock       $ 1.29
# 2708469                                      Rock       $ 0.99
# 2708467                                      Rock       $ 0.99
# 2708466                                      Rock       $ 0.99
# 2708465                                      Rock       $ 0.99
# 2708468                                      Rock       $ 0.99
# 2754947                                   Country       $ 1.29
# 2754946                                   Country       $ 1.29
# 2754945                                   Country       $ 1.29
# 2754944                                   Country       $ 1.29
# 2754943                                   Country       $ 1.29
# 2754942                                   Country       $ 1.29
# 1487981                                       Pop       $ 1.29
# 1255287                        Dance & Electronic       $ 1.29
# 1173783                          Alternative Rock       $ 0.99
# 1173784                          Alternative Rock       $ 0.99
# 1173785                          Alternative Rock       $ 0.99
# 1173786                          Alternative Rock       $ 0.99
# 1173787                          Alternative Rock       $ 0.99
# 2023743                                       Pop       $ 1.29
# 1652525                             Rap & Hip-Hop       $ 1.29
# 405803                                    Country       $ 1.29
# 825156                                    Country       $ 1.29
# 2024361  Electronica , Dance & Electronic , House       $ 1.29
# 245446                           Alternative Rock       $ 1.29
# 2415157       Singer-Songwriters , Pop Rock , Pop       $ 0.99
# 2877861  R&B , Rock , Rap Rock , Contemporary R&B       $ 0.99
#
#                                                                                             rtable_CopyRight  \
# _id
# 2629510                                                                     ( C ) 2014 EMI Records Nashville
# 2629654                                                                     ( C ) 2014 EMI Records Nashville
# 609582                                                                                    2011 Because Music
# 609584                                                                                    2011 Because Music
# 609576                                                                                    2011 Because Music
# 609579                                                                                    2011 Because Music
# 609580                                                                                    2011 Because Music
# 609583                                                                                    2011 Because Music
# 609577                                                                                    2011 Because Music
# 609578                                                                                    2011 Because Music
# 609581                                                                                    2011 Because Music
# 1046836  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1046839  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1046838  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1046837  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1046840  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1046844  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1046841  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1046835  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1046834  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1046842  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1046843  ( C ) 2007 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viol...
# 1572056                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1572045                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1572049                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1572052                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1572054                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1572055                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1572044                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1572036                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# ...                                                                                                      ...
# 1652660  2010 Atlantic Recording Corporation for the United States and WEA International Inc. for the wor...
# 2203917                                                                            ( C ) 2010 Geffen Records
# 1316439                                                                ( C ) 2010 Bad Boy/Interscope Records
# 2802140  2013 Atlantic Recording Corporation for the United States and WEA International Inc. for the wor...
# 2708469                                                                                       2005 Z Records
# 2708467                                                                                       2005 Z Records
# 2708466                                                                                       2005 Z Records
# 2708465                                                                                       2005 Z Records
# 2708468                                                                                       2005 Z Records
# 2754947                                                                 ( C ) 2008 Big Machine Records , LLC
# 2754946                                                                 ( C ) 2008 Big Machine Records , LLC
# 2754945                                                                 ( C ) 2008 Big Machine Records , LLC
# 2754944                                                                 ( C ) 2008 Big Machine Records , LLC
# 2754943                                                                 ( C ) 2008 Big Machine Records , LLC
# 2754942                                                                 ( C ) 2008 Big Machine Records , LLC
# 1487981                                                                 ( C ) 2014 Disney Enterprises , Inc.
# 1255287                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1173783                                                            ( C ) 2007 The Island Def Jam Music Group
# 1173784                                                            ( C ) 2007 The Island Def Jam Music Group
# 1173785                                                            ( C ) 2007 The Island Def Jam Music Group
# 1173786                                                            ( C ) 2007 The Island Def Jam Music Group
# 1173787                                                            ( C ) 2007 The Island Def Jam Music Group
# 2023743                                                                                           2013 OWSLA
# 1652525  2010 Atlantic Recording Corporation for the United States and WEA International Inc. for the wor...
# 405803                                                                      ( C ) 2013 EMI Records Nashville
# 825156                       ( C ) 2011 Hit Red Records under exclusive license to Capitol Records Nashville
# 2024361                                                                                        Start records
# 245446                                                             ( C ) 2009 The Island Def Jam Music Group
# 2415157                                                                               ( c ) 2012 TDT Records
# 2877861                                                                   ( C ) 2010 Cash Money Records Inc.
#
#         rtable_Time     rtable_Released
# _id
# 2629510        4:22  February 11 , 2014
# 2629654        4:22  February 11 , 2014
# 609582         5:14       June 1 , 2015
# 609584         5:14       June 1 , 2015
# 609576         5:14       June 1 , 2015
# 609579         5:14       June 1 , 2015
# 609580         5:14       June 1 , 2015
# 609583         5:14       June 1 , 2015
# 609577         5:14       June 1 , 2015
# 609578         5:14       June 1 , 2015
# 609581         5:14       June 1 , 2015
# 1046836        4:02    August 14 , 2007
# 1046839        4:02    August 14 , 2007
# 1046838        4:02    August 14 , 2007
# 1046837        4:02    August 14 , 2007
# 1046840        4:02    August 14 , 2007
# 1046844        4:02    August 14 , 2007
# 1046841        4:02    August 14 , 2007
# 1046835        4:02    August 14 , 2007
# 1046834        4:02    August 14 , 2007
# 1046842        4:02    August 14 , 2007
# 1046843        4:02    August 14 , 2007
# 1572056        4:34  November 10 , 2014
# 1572045        4:34  November 10 , 2014
# 1572049        4:34  November 10 , 2014
# 1572052        4:34  November 10 , 2014
# 1572054        4:34  November 10 , 2014
# 1572055        4:34  November 10 , 2014
# 1572044        4:34  November 10 , 2014
# 1572036        4:34  November 10 , 2014
# ...             ...                 ...
# 1652660        3:52  November 24 , 2010
# 2203917        3:54  November 16 , 2010
# 1316439        4:04  December 14 , 2010
# 2802140        4:02       May 28 , 2013
# 2708469        3:37      June 24 , 2008
# 2708467        3:37      June 24 , 2008
# 2708466        3:37      June 24 , 2008
# 2708465        3:37      June 24 , 2008
# 2708468        3:37      June 24 , 2008
# 2754947        3:52   December 2 , 2008
# 2754946        3:52   December 2 , 2008
# 2754945        3:52   December 2 , 2008
# 2754944        3:52   December 2 , 2008
# 2754943        3:52   December 2 , 2008
# 2754942        3:52   December 2 , 2008
# 1487981        3:17  November 25 , 2013
# 1255287        7:02   October 27 , 2014
# 1173783        3:32  November 20 , 2007
# 1173784        3:32  November 20 , 2007
# 1173785        3:32  November 20 , 2007
# 1173786        3:32  November 20 , 2007
# 1173787        3:32  November 20 , 2007
# 2023743        5:20   October 20 , 2014
# 1652525        3:36  November 26 , 2010
# 405803         4:55      April 5 , 2013
# 825156         3:55  February 22 , 2011
# 2024361        3:42     March 23 , 2015
# 245446         3:35  November 16 , 2009
# 2415157        3:49        May 1 , 2012
# 2877861        2:52      June 15 , 2010
#
# [5122 rows x 19 columns]

# %% [markdown]
# As you have seen, `deepmatcher` does not include a column indicating match / non-match predictions in the output table. You can easily create such a column by thresholding the `match_score` at 0.5 (which is what `deepmatcher` uses as the threshold to compute F1), or using a threshold value or your choice.

# %%
predictions['match_prediction'] = predictions['match_score'] >= 0.5

# Reorder columns to avoid scrolling...
predictions =  predictions[['match_score', 'match_prediction'] + predictions.columns.values[1:-1].tolist()]
predictions.head()
# Out:
#       match_score  match_prediction  ltable_id  rtable_id  \
# _id
# 3237     0.831005              True       2583        228
# 3238     0.404846             False       2003        229
# 3239     0.404846             False       2574        229
# 3240     0.404846             False       2575        229
# 3323     0.489662             False       2003        230
#
#                   ltable_Song_Name ltable_Artist_Name  \
# _id
# 3237  #Selfie ( Instrumental Mix )   The Chainsmokers
# 3238    #SELFIE ( Caked Up Remix )   The Chainsmokers
# 3239    #SELFIE ( Caked Up Remix )   The Chainsmokers
# 3240    #SELFIE ( Caked Up Remix )   The Chainsmokers
# 3323    #SELFIE ( Caked Up Remix )   The Chainsmokers
#
#                           ltable_Album_Name                ltable_Genre  \
# _id
# 3237  #Selfie ( Instrumental Mix ) - Single  Dance , Music , Electronic
# 3238       #SELFIE ( The Remixes ) - Single  Electronic , Music , Dance
# 3239       #SELFIE ( The Remixes ) - Single  Electronic , Music , Dance
# 3240       #SELFIE ( The Remixes ) - Single  Electronic , Music , Dance
# 3323       #SELFIE ( The Remixes ) - Single  Electronic , Music , Dance
#
#      ltable_Price  \
# _id
# 3237       $ 1.29
# 3238       $ 1.29
# 3239       $ 1.29
# 3240       $ 1.29
# 3323       $ 1.29
#
#                                                                                          ltable_CopyRight  \
# _id
# 3237  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , Inc.
# 3238  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3239  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3240  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
# 3323  2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordings , I...
#
#      ltable_Time ltable_Released               rtable_Song_Name  \
# _id
# 3237        3:03       20-Mar-14   #SELFIE ( Instrumental Mix )
# 3238        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3239        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3240        3:15       17-Jun-14  #Selfie ( Will Sparks Remix )
# 3323        3:15       17-Jun-14       #Selfie ( Botnek Remix )
#
#      rtable_Artist_Name             rtable_Album_Name  \
# _id
# 3237   The Chainsmokers  #SELFIE ( Instrumental Mix )
# 3238   The Chainsmokers       #Selfie ( The Remixes )
# 3239   The Chainsmokers       #Selfie ( The Remixes )
# 3240   The Chainsmokers       #Selfie ( The Remixes )
# 3323   The Chainsmokers       #Selfie ( The Remixes )
#
#                           rtable_Genre rtable_Price  \
# _id
# 3237                Dance & Electronic       $ 1.29
# 3238  Electronica , Dance & Electronic       $ 1.29
# 3239  Electronica , Dance & Electronic       $ 1.29
# 3240  Electronica , Dance & Electronic       $ 1.29
# 3323  Electronica , Dance & Electronic       $ 1.29
#
#                                                                                          rtable_CopyRight  \
# _id
# 3237  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3238  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3239  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3240  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
# 3323  ( C ) 2014 Dim Mak Inc. under exclusive license to Republic Records , a Division of UMG Recordin...
#
#      rtable_Time  rtable_Released
# _id
# 3237        3:03  March 20 , 2014
# 3238        3:52   June 17 , 2014
# 3239        3:52   June 17 , 2014
# 3240        3:52   June 17 , 2014
# 3323        3:36   June 17 , 2014
