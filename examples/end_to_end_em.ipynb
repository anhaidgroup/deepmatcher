# %% [markdown]
# # Introduction

# %% [markdown]
# As a part of the ***Magellan*** ecosystem, in this tutorial we will show how to use `deepmatcher` together with `Magellan`, to perform an end-to-end Entity Matching (EM) task. Specifically, `Magellan` performs EM in a **two-stage** fashion where given two tables,
# 1. Perform **blocking** on the two tables by removing obvious non-matching tuple pairs to get a candidate set K.
# 2. Perform **matching** to predict each pair in K as match or non-match. This stage consists of the following substeps:
#     1. *Magellan* first helps the user take a sample S from K.
#     2. The user labels all pairs in S as the training data.
#     3. A classifer L will be learned on S.
#     4. The user applies L to K to predict each pair as match or non-match.
#
# Given the above workflow, `deepmatcher` fits in the step C, which is to take advantage of deep learning to learn a classifer. For the rest of the tutorial, we will use a real example, which is to match songs across two tables from iTunes and Amazon Music, to go through the workflow.
#
# For more information on `Magellan`, please go to the project website: https://sites.google.com/site/anhaidgroup/projects/magellan.

# %% [markdown]
# # Step 0. Preparation
# In order to use ***Magellan***, we need to first install it. The easiest way is to use "pip" as follow (please consult the package website for other installation options).

# %%
# Install Magellan.
try:
    import py_entitymatching as em
except:
    # !pip install py_entitymatching

# %%
# Importdeepmatcher.
import deepmatcher as dm

import os

# %% [markdown]
# # Step 1. Load data
# We first load the two input tables in the csv format using `Magellan`, that contain songs from iTunes and Amazon Music. These two tables are in the "example" directory included in our package.

# %%
# The path to the two input tables.
path_A = os.path.join('.', 'sample_data', 'itunes-amazon', 'tableA.csv')
path_B = os.path.join('.', 'sample_data', 'itunes-amazon', 'tableB.csv')

# %%
# Load the two tables.
A = em.read_csv_metadata(path_A, key='id')
B = em.read_csv_metadata(path_B, key='id')
# Out:
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.

# %%
# Basic information about the tables.
print('Number of tuples in A: ' + str(len(A)))
print('Number of tuples in B: ' + str(len(B)))
print('Number of tuples in A X B (i.e the cartesian product): ' + str(len(A)*len(B)))
# Out:
# Number of tuples in A: 6907
# Number of tuples in B: 55923
# Number of tuples in A X B (i.e the cartesian product): 386260161

# %%
# The first few tuples in table A.
A.head()
# Out:
#    id                            Song_Name        Artist_Name  \
# 0   0                        Runaway Train                Cam
# 1   1                             Track 14                Omi
# 2   2                       Lips Are Movin     Meghan Trainor
# 3   3  I Want a Hippopotamus for Christmas  A Great Big World
# 4   4                               Credit     Meghan Trainor
#
#                     Album_Name  \
# 0  Welcome to Cam Country - EP
# 1                       Me 4 U
# 2                        Title
# 3  I 'll Be Home For Christmas
# 4             Title ( Deluxe )
#
#                                                  Genre       Price  \
# 0  Country , Music , Contemporary Country , Honky Tonk      $ 0.99
# 1          Pop/Rock , Music , Pop , Dance , R&B / Soul  Album Only
# 2     Pop , Music , Pop/Rock , Dance , Rock , Teen Pop      $ 1.29
# 3                                      Holiday , Music      $ 1.29
# 4     Pop , Music , Rock , Pop/Rock , Dance , Teen Pop      $ 1.29
#
#                                                                                              CopyRight  \
# 0                                                                        2015 Sony Music Entertainment
# 1  2015 Ultra Records , LLC under exclusive license to Columbia Records , a Division of Sony Music ...
# 2                                    2014 , 2015 Epic Records , a division of Sony Music Entertainment
# 3                         Compilation ( P ) 2014 Epic Records , a division of Sony Music Entertainment
# 4                                    2014 , 2015 Epic Records , a division of Sony Music Entertainment
#
#    Time   Released
# 0  3:01  31-Mar-15
# 1  3:41        NaN
# 2  3:01   9-Jan-15
# 3  2:20  24-Nov-14
# 4  2:51   9-Jan-15

# %%
# The first few tuples in table B.
B.head()
# Out:
#    id                          Song_Name Artist_Name  \
# 0   0       Saxophone Stomp [ Explicit ]       Rusko
# 1   1  I Wan na Mingle [ feat . Pusher ]       Rusko
# 2   2                              Lytah       Rusko
# 3   3                       Slappy Pappy       Rusko
# 4   4                        Fushion Jam       Rusko
#
#                     Album_Name                         Genre   Price  \
# 0  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 1  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 2  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 3  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
# 4  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep  $ 1.29
#
#                                                                 CopyRight  \
# 0  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 1  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 2  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 3  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 4  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
#
#    Time             Released
# 0  3:20  September 16 , 2014
# 1  2:36  September 16 , 2014
# 2  3:48  September 16 , 2014
# 3  3:55  September 16 , 2014
# 4  1:48  September 16 , 2014

# %% [markdown]
# # Step 2. Block tables to get the candidate set
# We first perform blocking on A and B to get a candidate set K, by removing obvious non-matching tuple pairs. `Magellan` supports four different types of blocker: (1) attribute equivalence, (2) overlap, (3) rule-based, and (4) black-box. Typically, users need to mix and match these blockers with the debugging functionality provided in `Magellan` to get a good candidate set. (Developing a good blocker is not the focus of this tutorial. For more information on developing and debugging a blocker, please consult the user manual of `Magellan`.)
#
# Here we show an example of blocking. Observe that matching tuple pairs should have some common words in the album name, so we first create an overlap blocker on the attribute name "Album_Name" with threshold 2, to remove all pairs with word overlap less 2 in that attribute.

# %%
# Create an overlap blocker in Magellan and apply it to A and B to get the candidate set K1 which is in the format of 
# a dataframe. The "l_out_attrs" and "r_out_attrs" parameters indicate the columns that will be included in K1 from A
# and B respectively.
ob = em.OverlapBlocker()
K1 = ob.block_tables(A, B, 'Album_Name', 'Album_Name',
                    l_output_attrs=['Song_Name', 'Artist_Name', 'Album_Name', 'Genre', 'Price', 'CopyRight', 'Time', 'Released'], 
                    r_output_attrs=['Song_Name', 'Artist_Name', 'Album_Name', 'Genre', 'Price', 'CopyRight', 'Time', 'Released'],
                    overlap_size=2)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:18

# %%
# The number of tuple pairs in K1.
len(K1)
# Out:
# 3152021

# %%
# The first few tuple pairs in K1
K1.head()
# Out:
#    _id  ltable_id  rtable_id ltable_Song_Name ltable_Artist_Name  \
# 0    0       3995          0     Rudolph Blue      Brian Fechino
# 1    1       3995          1     Rudolph Blue      Brian Fechino
# 2    2       3995          2     Rudolph Blue      Brian Fechino
# 3    3       3995          3     Rudolph Blue      Brian Fechino
# 4    4       3995          4     Rudolph Blue      Brian Fechino
#
#                           ltable_Album_Name            ltable_Genre  \
# 0  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 1  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 2  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 3  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
# 4  A Rock By The Sea Christmas : : Volume 2  Holiday , Music , Rock
#
#   ltable_Price ltable_CopyRight ltable_Time ltable_Released  \
# 0       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 1       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 2       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 3       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
# 4       $ 0.99    2011 Hubbub !        1:57        8-Nov-11
#
#                     rtable_Song_Name rtable_Artist_Name  \
# 0       Saxophone Stomp [ Explicit ]              Rusko
# 1  I Wan na Mingle [ feat . Pusher ]              Rusko
# 2                              Lytah              Rusko
# 3                       Slappy Pappy              Rusko
# 4                        Fushion Jam              Rusko
#
#              rtable_Album_Name                  rtable_Genre rtable_Price  \
# 0  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 1  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 2  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 3  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
# 4  ! ( Volume 2 ) [ Explicit ]  Dance & Electronic , Dubstep       $ 1.29
#
#                                                          rtable_CopyRight  \
# 0  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 1  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 2  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 3  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
# 4  ( C ) 2014 FMLY Under Exclusive License To Universal Music Canada Inc.
#
#   rtable_Time      rtable_Released
# 0        3:20  September 16 , 2014
# 1        2:36  September 16 , 2014
# 2        3:48  September 16 , 2014
# 3        3:55  September 16 , 2014
# 4        1:48  September 16 , 2014

# %% [markdown]
# Notice that K1 has more than 3 million pair in it, which is too large to considered for matching. So we create an overlap blocking with threshold 1 on the attribute "Artist_Name" for K1, to filter all pairs in K1 that don't share any word in "Artist_Name". And we get the candidate set K2.

# %%
# Create a new overlap blocker to remove pairs from K1 that have no common word in "Artist_Name".
K2 = ob.block_candset(K1, 'Artist_Name', 'Artist_Name', overlap_size=1)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:30

# %%
# The number of tuple pairs in K2.
len(K2)
# Out:
# 167180

# %% [markdown]
# After the second blocking step, now we have a candidate set K2 with about 170K pairs. But we think it is still a bit larger to consider for matching. So we apply a third blocker, which is an overlap blocker on the attribute "Song_Name", to further reduce the size of the candidate set.

# %%
# Apply the third overlap blocker.
K3 = ob.block_candset(K2, 'Song_Name', 'Song_Name', overlap_size=1)
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:01

# %%
# The number of tuples pairs in K3.
len(K3)
# Out:
# 38015

# %% [markdown]
# Now we have a candidate set with 38K pairs which is reasonable, so we take K3 as the final candidate set. We save the candidate to the disk in the csv format for future reuse.

# %%
path_K = os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial', 'candidate.csv')
K3.to_csv(path_K, index=False)

# %% [markdown]
# # Step 3. Match tuple pairs in the candidate set
# In this stage we will match tuple pairs in the candidate set to predict each of them as match or non-match. This is the part that `deepmatcher` will be involved. Specifically, it consists of the following steps:
# 1. Take a sample S from the candidate set K, and label all pairs in S.
# 2. Train a classifier L using S. Specifically, we will train a classifier using `deepmatcher`.
# 3. Apply L to the candidiate set K.

# %% [markdown]
# ## Sample and label the candidate set
# We first take a random sample S from the candidate set K using `Magellan`. Here for example, we sample 500 pairs for K. Then we label each pair as match (enter 1) or non-match (enter 0) and use S as the training data.

# %%
# Take a sample of 500 pairs from the candidate set.
S = em.sample_table(K3, 500)

# %%
# Label the sample S in a GUI. Enter 1 for match and 0 for non-match.
G = em.label_table(S, 'gold')

# %% [markdown]
# For the purposes of this tutorial, we will load in a pre-labeled dataset (of 539 tuple pairs) included in this package.

# %%
# The path to the labeled data file.
path_G = os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial', 'gold.csv')

# %%
# Load the labeled data into a dataframe.
G = em.read_csv_metadata(path_G, 
                         key='_id',
                         ltable=A, rtable=B, 
                         fk_ltable='ltable_id', fk_rtable='rtable_id')
print('Number of labeled pairs:', len(G))
# Out:
# WARNING:py_entitymatching.io.parsers:Metadata file is not present in the given path; proceeding to read the csv file.
# Number of labeled pairs: 539

# %% [markdown]
# ## Train a classifier using labeled data
# Once we have the labeled data, we use `deepmatcher` to train a classifier. The first thing we need to do is to split the data for training purpose. In this example, we split the labeled data into three parts: training, validation and test data, with the ratio of 3:1:1. (For now we only support spliting the labeled data into three parts train/valid/test, where the validation set is used for selecting the best model during the training epochs.) For the purpose of caching data and progressive training, we will first save the split parts to disk in the format of csv files, then load them back in. The cache file will be saved during the loading procedure. For subsequent training runs, the cache file will be used to save preprocessing time on the raw csv files, unless the csv files are modified (in this case, new cache file will be generated).

# %%
# The directory where the data splits will be saved.
split_path = os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial')

# %%
# Split labeled data into train, valid, and test csv files to disk, with the split ratio of 3:1:1.
dm.data.split(G, split_path, 'train.csv', 'valid.csv', 'test.csv',
              [3, 1, 1])

# %%
# Load the training data files from the disk. Ignore the "left_id" and "right_id" 
# columns for data preprocessing.
train, validation, test = dm.data.process(
    path=os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial'),
    cache='train_cache.pth',
    train='train.csv',
    validation='valid.csv',
    test='test.csv',
    left_prefix='ltable_',
    right_prefix='rtable_',
    id_attr='_id',
    ignore_columns=('ltable_id', 'rtable_id'))
# Out:
# Load time: 0.7007005997002125
# Vocab time: 13.327638105489314
# Metadata time: 0.3369469679892063
# Cache time: 0.5706925522536039

# %% [markdown]
# After we get the training data, we can use `deepmatcher` to train a classifier. Here we train a hybrid model.

# %%
# Create a hybrid model.
model = dm.MatchingModel(attr_summarizer='hybrid')

# %%
# Train the hybrid model with 10 training epochs, batch size of 16, positive-to-negative 
# ratio to be 3. We save the best model (with the 
# highest F1 score on the validation set) to 'hybrid_model.pth'.
model.run_train(
    train,
    validation,
    epochs=10,
    batch_size=16,
    best_save_path='hybrid_model.pth',
    pos_neg_ratio=3)
# Out:
# * Number of trainable parameters: 17757810
# ===>  TRAIN Epoch 1 :
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 1 || Run Time:    4.2 | Load Time:    0.5 || F1:  52.00 | Prec:  44.07 | Rec:  63.41 || Ex/s:  68.76
#
# ===>  EVAL Epoch 1 :
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 1 || Run Time:    0.6 | Load Time:    0.2 || F1:  49.35 | Prec:  33.33 | Rec:  95.00 || Ex/s: 133.96
#
# * Best F1: 49.35064935064935
# Saving best model...
# ===>  TRAIN Epoch 2 :
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 2 || Run Time:    3.9 | Load Time:    0.5 || F1:  71.43 | Prec:  61.40 | Rec:  85.37 || Ex/s:  72.61
#
# ===>  EVAL Epoch 2 :
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 2 || Run Time:    0.6 | Load Time:    0.2 || F1:  53.52 | Prec:  37.25 | Rec:  95.00 || Ex/s: 141.35
#
# * Best F1: 53.521126760563384
# Saving best model...
# ===>  TRAIN Epoch 3 :
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 3 || Run Time:    3.9 | Load Time:    0.5 || F1:  75.86 | Prec:  71.74 | Rec:  80.49 || Ex/s:  72.55
#
# ===>  EVAL Epoch 3 :
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 3 || Run Time:    0.6 | Load Time:    0.2 || F1:  72.34 | Prec:  62.96 | Rec:  85.00 || Ex/s: 140.88
#
# * Best F1: 72.3404255319149
# Saving best model...
# ===>  TRAIN Epoch 4 :
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 4 || Run Time:    3.9 | Load Time:    0.5 || F1:  83.98 | Prec:  76.77 | Rec:  92.68 || Ex/s:  72.70
#
# ===>  EVAL Epoch 4 :
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 4 || Run Time:    0.6 | Load Time:    0.2 || F1:  76.92 | Prec:  78.95 | Rec:  75.00 || Ex/s: 140.51
#
# * Best F1: 76.92307692307692
# Saving best model...
# ===>  TRAIN Epoch 5 :
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 5 || Run Time:    4.0 | Load Time:    0.5 || F1:  87.36 | Prec:  82.61 | Rec:  92.68 || Ex/s:  71.22
#
# ===>  EVAL Epoch 5 :
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 5 || Run Time:    0.6 | Load Time:    0.2 || F1:  80.95 | Prec:  77.27 | Rec:  85.00 || Ex/s: 140.10
#
# * Best F1: 80.95238095238096
# Saving best model...
# ===>  TRAIN Epoch 6 :
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 6 || Run Time:    3.9 | Load Time:    0.5 || F1:  92.40 | Prec:  88.76 | Rec:  96.34 || Ex/s:  73.07
#
# ===>  EVAL Epoch 6 :
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 6 || Run Time:    0.6 | Load Time:    0.2 || F1:  76.60 | Prec:  66.67 | Rec:  90.00 || Ex/s: 135.66
#
# ===>  TRAIN Epoch 7 :
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 7 || Run Time:    3.9 | Load Time:    0.5 || F1:  94.74 | Prec:  91.01 | Rec:  98.78 || Ex/s:  73.03
#
# ===>  EVAL Epoch 7 :
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 7 || Run Time:    0.6 | Load Time:    0.2 || F1:  78.26 | Prec:  69.23 | Rec:  90.00 || Ex/s: 136.69
#
# ===>  TRAIN Epoch 8 :
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 8 || Run Time:    4.0 | Load Time:    0.5 || F1:  97.01 | Prec:  95.29 | Rec:  98.78 || Ex/s:  72.24
#
# ===>  EVAL Epoch 8 :
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 8 || Run Time:    0.6 | Load Time:    0.2 || F1:  80.00 | Prec:  72.00 | Rec:  90.00 || Ex/s: 140.01
#
# ===>  TRAIN Epoch 9 :
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 9 || Run Time:    4.0 | Load Time:    0.5 || F1:  98.20 | Prec:  96.47 | Rec: 100.00 || Ex/s:  71.44
#
# ===>  EVAL Epoch 9 :
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 9 || Run Time:    0.6 | Load Time:    0.2 || F1:  80.00 | Prec:  72.00 | Rec:  90.00 || Ex/s: 139.81
#
# ===>  TRAIN Epoch 10 :
# 0% [████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:04
# Finished Epoch 10 || Run Time:    3.9 | Load Time:    0.5 || F1:  98.80 | Prec:  97.62 | Rec: 100.00 || Ex/s:  72.48
#
# ===>  EVAL Epoch 10 :
# 0% [█] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Finished Epoch 10 || Run Time:    0.6 | Load Time:    0.2 || F1:  80.00 | Prec:  72.00 | Rec:  90.00 || Ex/s: 140.17
#
# Loading best model...

# %% [markdown]
# Once we have the trained classifier, we can evaluate the accuracy using the test data.

# %%
# Evaluate the accuracy on the test data.
model.run_eval(test)
# Out:
# ===>  EVAL Epoch 5 :
# Finished Epoch 5 || Run Time:    0.3 | Load Time:    0.2 || F1:  87.72 | Prec:  92.59 | Rec:  83.33 || Ex/s: 197.83
# 87.71929824561403

# %% [markdown]
# ## Apply the trained classifier to the candidate set
# Now we have a trained classifer, we can apply it to the candidate set to predict each pair as match or non-match. To achieve this, we first load the trained model and the candidate set.

# %%
# Load the model.
model = dm.MatchingModel(attr_summarizer='hybrid')
model.load_state('hybrid_model.pth')

# %%
# Load the candidate set. Note that the trained model is an input parameter as we need to trained 
# model for candidate set preprocessing.
candidate = dm.data.process_unlabeled(
    path=os.path.join('.', 'sample_data', 'itunes-amazon', 'e2e-tutorial', 'candidate.csv'),
    trained_model=model,
    ignore_columns=('ltable_id', 'rtable_id'))
# Out:
# Load time: 38.985889066010714
# Vocab update time: 0.7389105502516031

# %% [markdown]
# After we load the candidate set, now we make the predictions using the `run_prediction` function. The *output_attribute* argument indicates the columns that will be included in the prediction table. Here
# we use all of the columns in the candidate set.

# %%
# Predict the pairs in the candidate set and return a dataframe containing the pair id with 
# the score of being a match.
predictions = model.run_prediction(candidate, output_attributes=list(candidate.get_raw_table().columns))
# Out:
# ===>  PREDICT Epoch 5 :
# 0% [██████████████████████████████] 100% | ETA: 00:00:00
# Total time elapsed: 00:02:28
# Finished Epoch 5 || Run Time:  100.2 | Load Time:   48.6 || F1:   0.00 | Prec:   0.00 | Rec:   0.00 || Ex/s:   0.00

# %% [markdown]
# Below shows a few pairs in the prediction table. Note that this table is not sorted in the descending order of the
# match scores.

# %%
predictions.head()
# Out:
#         match_score  ltable_id  rtable_id    ltable_Song_Name  \
# _id
# 690110     0.978090       3354      17626  Extra Extra Credit
# 690109     0.978090       3353      17626  Extra Extra Credit
# 690108     0.978090       3336      17626  Extra Extra Credit
# 690209     0.080678       3354      17659  Extra Extra Credit
# 690208     0.080678       3353      17659  Extra Extra Credit
#
#        ltable_Artist_Name ltable_Album_Name         ltable_Genre ltable_Price  \
# _id
# 690110        Wiz Khalifa     Flight School  Hip-Hop/Rap , Music       $ 0.99
# 690109        Wiz Khalifa     Flight School  Hip-Hop/Rap , Music       $ 0.99
# 690108        Wiz Khalifa     Flight School  Hip-Hop/Rap , Music       $ 0.99
# 690209        Wiz Khalifa     Flight School  Hip-Hop/Rap , Music       $ 0.99
# 690208        Wiz Khalifa     Flight School  Hip-Hop/Rap , Music       $ 0.99
#
#             ltable_CopyRight ltable_Time ltable_Released  \
# _id
# 690110  2009 Rostrum Records        4:03       17-Apr-09
# 690109  2009 Rostrum Records        4:03       17-Apr-09
# 690108  2009 Rostrum Records        4:03       17-Apr-09
# 690209  2009 Rostrum Records        4:03       17-Apr-09
# 690208  2009 Rostrum Records        4:03       17-Apr-09
#
#                        rtable_Song_Name rtable_Artist_Name  \
# _id
# 690110  Extra Extra Credit [ Explicit ]        Wiz Khalifa
# 690109  Extra Extra Credit [ Explicit ]        Wiz Khalifa
# 690108  Extra Extra Credit [ Explicit ]        Wiz Khalifa
# 690209        Extra Credit [ Explicit ]        Wiz Khalifa
# 690208        Extra Credit [ Explicit ]        Wiz Khalifa
#
#                  rtable_Album_Name   rtable_Genre rtable_Price  \
# _id
# 690110  Flight School [ Explicit ]  Rap & Hip-Hop       $ 0.99
# 690109  Flight School [ Explicit ]  Rap & Hip-Hop       $ 0.99
# 690108  Flight School [ Explicit ]  Rap & Hip-Hop       $ 0.99
# 690209  Flight School [ Explicit ]  Rap & Hip-Hop       $ 0.99
# 690208  Flight School [ Explicit ]  Rap & Hip-Hop       $ 0.99
#
#        rtable_CopyRight rtable_Time  rtable_Released
# _id
# 690110  2013 Mad Decent        4:03  April 17 , 2009
# 690109  2013 Mad Decent        4:03  April 17 , 2009
# 690108  2013 Mad Decent        4:03  April 17 , 2009
# 690209  2013 Mad Decent        3:23  April 17 , 2009
# 690208  2013 Mad Decent        3:23  April 17 , 2009

# %% [markdown]
# We can simply manipulate the prediction table above to get the pairs that we want. Suppose we are only interested in pairs with the match score more over 0.9, and we want to display them sorting in the descending order on match score. This can be achieved as follow.

# %%
high_score_pairs = predictions[predictions['match_score'] >= 0.9].sort_values(by=['match_score'], ascending=False)
high_score_pairs
# Out:
#          match_score  ltable_id  rtable_id               ltable_Song_Name  \
# _id
# 221538      0.999012       4316       6130                         Remark
# 221540      0.999012       4318       6130                         Remark
# 221532      0.999012       4309       6130                         Remark
# 221531      0.999012       4308       6130                         Remark
# 221535      0.999012       4312       6130                         Remark
# 221536      0.999012       4313       6130                         Remark
# 221537      0.999012       4315       6130                         Remark
# 221539      0.999012       4317       6130                         Remark
# 221534      0.999012       4311       6130                         Remark
# 221533      0.999012       4310       6130                         Remark
# 2878652     0.995624       5724      50854           Late Night Automatic
# 128408      0.995591       5730       4498                          Smile
# 128120      0.995591       5730       4474                          Smile
# 128264      0.995591       5730       4486                          Smile
# 127976      0.995591       5730       4462                          Smile
# 2877861     0.995428       5717      50847                     Do n't Cry
# 511692      0.995232       6239      13718                      Apologize
# 2022849     0.994737       6301      42380                         Sierra
# 2022728     0.994737       6301      42369                         Sierra
# 2022607     0.994737       6301      42358                         Sierra
# 2022486     0.994737       6301      42347                         Sierra
# 1133349     0.994659       2431      24297  I 'd Love to Change Your Name
# 1133350     0.994659       2451      24297  I 'd Love to Change Your Name
# 1133356     0.994659       2474      24297  I 'd Love to Change Your Name
# 1133352     0.994659       2461      24297  I 'd Love to Change Your Name
# 1133353     0.994659       2463      24297  I 'd Love to Change Your Name
# 1133354     0.994659       2466      24297  I 'd Love to Change Your Name
# 1133351     0.994659       2456      24297  I 'd Love to Change Your Name
# 1133355     0.994659       2469      24297  I 'd Love to Change Your Name
# 1133338     0.993932       2474      24295  I 'd Love to Change Your Name
# ...              ...        ...        ...                            ...
# 1567592     0.900508        396      33279        Nothing Would Be Better
# 1567598     0.900508        404      33279        Nothing Would Be Better
# 1567597     0.900508        403      33279        Nothing Would Be Better
# 1567617     0.900508        432      33279        Nothing Would Be Better
# 1567601     0.900508        407      33279        Nothing Would Be Better
# 1568290     0.900508        394      33293        Nothing Would Be Better
# 1568289     0.900508        393      33293        Nothing Would Be Better
# 1568287     0.900508        391      33293        Nothing Would Be Better
# 1567619     0.900508        434      33279        Nothing Would Be Better
# 1567591     0.900508        395      33279        Nothing Would Be Better
# 941816      0.900501       4987      21486                Keep the Change
# 1608045     0.900470       5117      34108                 Furthest Thing
# 1569681     0.900208        382      33321        Nothing Would Be Better
# 1569022     0.900208        437      33307        Nothing Would Be Better
# 1569686     0.900208        388      33321        Nothing Would Be Better
# 1569002     0.900208        409      33307        Nothing Would Be Better
# 1569006     0.900208        418      33307        Nothing Would Be Better
# 1569005     0.900208        417      33307        Nothing Would Be Better
# 1569004     0.900208        416      33307        Nothing Would Be Better
# 1568999     0.900208        405      33307        Nothing Would Be Better
# 1568995     0.900208        401      33307        Nothing Would Be Better
# 1568994     0.900208        400      33307        Nothing Would Be Better
# 1568993     0.900208        399      33307        Nothing Would Be Better
# 1568986     0.900208        388      33307        Nothing Would Be Better
# 1568981     0.900208        382      33307        Nothing Would Be Better
# 2942015     0.900190       6132      52141                   Black Beauty
# 2941805     0.900190       6132      52127                   Black Beauty
# 128225      0.900170       5727       4483                       Sun Daze
# 128369      0.900170       5727       4495                       Sun Daze
# 128081      0.900170       5727       4471                       Sun Daze
#
#                    ltable_Artist_Name         ltable_Album_Name  \
# _id
# 221538                 Rachel Platten                   Be Here
# 221540                 Rachel Platten                   Be Here
# 221532                 Rachel Platten                   Be Here
# 221531                 Rachel Platten                   Be Here
# 221535                 Rachel Platten                   Be Here
# 221536                 Rachel Platten                   Be Here
# 221537                 Rachel Platten                   Be Here
# 221539                 Rachel Platten                   Be Here
# 221534                 Rachel Platten                   Be Here
# 221533                 Rachel Platten                   Be Here
# 2878652  Kevin Rudolf & Three 6 Mafia                To the Sky
# 128408           Florida Georgia Line             Anything Goes
# 128120           Florida Georgia Line             Anything Goes
# 128264           Florida Georgia Line             Anything Goes
# 127976           Florida Georgia Line             Anything Goes
# 2877861                  Kevin Rudolf                To the Sky
# 511692                     Luke Bryan           Doin ' My Thing
# 2022849                  Maddie & Tae                Start Here
# 2022728                  Maddie & Tae                Start Here
# 2022607                  Maddie & Tae                Start Here
# 2022486                  Maddie & Tae                Start Here
# 1133349                 Kenny Chesney      In My Wildest Dreams
# 1133350                 Kenny Chesney      In My Wildest Dreams
# 1133356                 Kenny Chesney      In My Wildest Dreams
# 1133352                 Kenny Chesney      In My Wildest Dreams
# 1133353                 Kenny Chesney      In My Wildest Dreams
# 1133354                 Kenny Chesney      In My Wildest Dreams
# 1133351                 Kenny Chesney      In My Wildest Dreams
# 1133355                 Kenny Chesney      In My Wildest Dreams
# 1133338                 Kenny Chesney      In My Wildest Dreams
# ...                               ...                       ...
# 1567592                    Nick Jonas                Nick Jonas
# 1567598                    Nick Jonas                Nick Jonas
# 1567597                    Nick Jonas                Nick Jonas
# 1567617                    Nick Jonas                Nick Jonas
# 1567601                    Nick Jonas                Nick Jonas
# 1568290                    Nick Jonas                Nick Jonas
# 1568289                    Nick Jonas                Nick Jonas
# 1568287                    Nick Jonas                Nick Jonas
# 1567619                    Nick Jonas                Nick Jonas
# 1567591                    Nick Jonas                Nick Jonas
# 941816                 Holly Williams              Here With Me
# 1608045                         Drake      Nothing Was the Same
# 1569681                    Nick Jonas                Nick Jonas
# 1569022                    Nick Jonas                Nick Jonas
# 1569686                    Nick Jonas                Nick Jonas
# 1569002                    Nick Jonas                Nick Jonas
# 1569006                    Nick Jonas                Nick Jonas
# 1569005                    Nick Jonas                Nick Jonas
# 1569004                    Nick Jonas                Nick Jonas
# 1568999                    Nick Jonas                Nick Jonas
# 1568995                    Nick Jonas                Nick Jonas
# 1568994                    Nick Jonas                Nick Jonas
# 1568993                    Nick Jonas                Nick Jonas
# 1568986                    Nick Jonas                Nick Jonas
# 1568981                    Nick Jonas                Nick Jonas
# 2942015                  Lana Del Rey  Ultraviolence ( Deluxe )
# 2941805                  Lana Del Rey  Ultraviolence ( Deluxe )
# 128225           Florida Georgia Line             Anything Goes
# 128369           Florida Georgia Line             Anything Goes
# 128081           Florida Georgia Line             Anything Goes
#
#                                                                                         ltable_Genre  \
# _id
# 221538   Pop , Music , Singer/Songwriter , Contemporary Singer/Songwriter , Rock , Adult Alternative
# 221540   Pop , Music , Singer/Songwriter , Contemporary Singer/Songwriter , Rock , Adult Alternative
# 221532   Pop , Music , Singer/Songwriter , Contemporary Singer/Songwriter , Rock , Adult Alternative
# 221531   Pop , Music , Singer/Songwriter , Contemporary Singer/Songwriter , Rock , Adult Alternative
# 221535   Pop , Music , Singer/Songwriter , Contemporary Singer/Songwriter , Rock , Adult Alternative
# 221536   Pop , Music , Singer/Songwriter , Contemporary Singer/Songwriter , Rock , Adult Alternative
# 221537   Pop , Music , Singer/Songwriter , Contemporary Singer/Songwriter , Rock , Adult Alternative
# 221539   Pop , Music , Singer/Songwriter , Contemporary Singer/Songwriter , Rock , Adult Alternative
# 221534   Pop , Music , Singer/Songwriter , Contemporary Singer/Songwriter , Rock , Adult Alternative
# 221533   Pop , Music , Singer/Songwriter , Contemporary Singer/Songwriter , Rock , Adult Alternative
# 2878652                                Pop,Music,Hip-Hop / Rap , Rap , R&B / Soul , Rock , Hard Rock
# 128408                            Country , Music , Honky Tonk , Urban Cowboy , Contemporary Country
# 128120                            Country , Music , Honky Tonk , Urban Cowboy , Contemporary Country
# 128264                            Country , Music , Honky Tonk , Urban Cowboy , Contemporary Country
# 127976                            Country , Music , Honky Tonk , Urban Cowboy , Contemporary Country
# 2877861                                Pop,Music,Hip-Hop / Rap , Rap , R&B / Soul , Rock , Hard Rock
# 511692                                                        Country , Music , Contemporary Country
# 2022849                  Country , Music , Rock , Contemporary Country , Pop , Pop/Rock , Honky Tonk
# 2022728                  Country , Music , Rock , Contemporary Country , Pop , Pop/Rock , Honky Tonk
# 2022607                  Country , Music , Rock , Contemporary Country , Pop , Pop/Rock , Honky Tonk
# 2022486                  Country , Music , Rock , Contemporary Country , Pop , Pop/Rock , Honky Tonk
# 1133349                                        Country , Music , Urban Cowboy , Contemporary Country
# 1133350                                        Country , Music , Urban Cowboy , Contemporary Country
# 1133356                                        Country , Music , Urban Cowboy , Contemporary Country
# 1133352                                        Country , Music , Urban Cowboy , Contemporary Country
# 1133353                                        Country , Music , Urban Cowboy , Contemporary Country
# 1133354                                        Country , Music , Urban Cowboy , Contemporary Country
# 1133351                                        Country , Music , Urban Cowboy , Contemporary Country
# 1133355                                        Country , Music , Urban Cowboy , Contemporary Country
# 1133338                                        Country , Music , Urban Cowboy , Contemporary Country
# ...                                                                                              ...
# 1567592                                                                Pop , Music , Pop/Rock , Rock
# 1567598                                                                Pop , Music , Pop/Rock , Rock
# 1567597                                                                Pop , Music , Pop/Rock , Rock
# 1567617                                                                Pop , Music , Pop/Rock , Rock
# 1567601                                                                Pop , Music , Pop/Rock , Rock
# 1568290                                                                Pop , Music , Pop/Rock , Rock
# 1568289                                                                Pop , Music , Pop/Rock , Rock
# 1568287                                                                Pop , Music , Pop/Rock , Rock
# 1567619                                                                Pop , Music , Pop/Rock , Rock
# 1567591                                                                Pop , Music , Pop/Rock , Rock
# 941816                                                    Country , Music , Rock , Adult Alternative
# 1608045                     Hip-Hop/Rap , Music , Rap , Hardcore Rap , R&B / Soul , Contemporary R&B
# 1569681                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1569022                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1569686                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1569002                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1569006                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1569005                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1569004                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1568999                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1568995                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1568994                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1568993                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1568986                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 1568981                       Pop , Music , Christian & Gospel , Gospel , Pop/Rock , Teen Pop , Rock
# 2942015                                               Alternative , Music , Rock , Adult Alternative
# 2941805                                               Alternative , Music , Rock , Adult Alternative
# 128225                            Country , Music , Honky Tonk , Urban Cowboy , Contemporary Country
# 128369                            Country , Music , Honky Tonk , Urban Cowboy , Contemporary Country
# 128081                            Country , Music , Honky Tonk , Urban Cowboy , Contemporary Country
#
#         ltable_Price  \
# _id
# 221538        $ 0.99
# 221540        $ 0.99
# 221532        $ 0.99
# 221531        $ 0.99
# 221535        $ 0.99
# 221536        $ 0.99
# 221537        $ 0.99
# 221539        $ 0.99
# 221534        $ 0.99
# 221533        $ 0.99
# 2878652       $ 0.99
# 128408        $ 1.29
# 128120        $ 1.29
# 128264        $ 1.29
# 127976        $ 1.29
# 2877861       $ 0.99
# 511692        $ 1.29
# 2022849       $ 1.29
# 2022728       $ 1.29
# 2022607       $ 1.29
# 2022486       $ 1.29
# 1133349       $ 0.99
# 1133350       $ 0.99
# 1133356       $ 0.99
# 1133352       $ 0.99
# 1133353       $ 0.99
# 1133354       $ 0.99
# 1133351       $ 0.99
# 1133355       $ 0.99
# 1133338       $ 0.99
# ...              ...
# 1567592       $ 1.29
# 1567598       $ 1.29
# 1567597       $ 1.29
# 1567617       $ 1.29
# 1567601       $ 1.29
# 1568290       $ 1.29
# 1568289       $ 1.29
# 1568287       $ 1.29
# 1567619       $ 1.29
# 1567591       $ 1.29
# 941816        $ 0.99
# 1608045       $ 1.29
# 1569681       $ 1.29
# 1569022       $ 1.29
# 1569686       $ 1.29
# 1569002       $ 1.29
# 1569006       $ 1.29
# 1569005       $ 1.29
# 1569004       $ 1.29
# 1568999       $ 1.29
# 1568995       $ 1.29
# 1568994       $ 1.29
# 1568993       $ 1.29
# 1568986       $ 1.29
# 1568981       $ 1.29
# 2942015       $ 1.29
# 2941805       $ 1.29
# 128225        $ 1.29
# 128369        $ 1.29
# 128081        $ 1.29
#
#                                                                                             ltable_CopyRight  \
# _id
# 221538                                                                              2011 Great Unknown , LLC
# 221540                                                                              2011 Great Unknown , LLC
# 221532                                                                              2011 Great Unknown , LLC
# 221531                                                                              2011 Great Unknown , LLC
# 221535                                                                              2011 Great Unknown , LLC
# 221536                                                                              2011 Great Unknown , LLC
# 221537                                                                              2011 Great Unknown , LLC
# 221539                                                                              2011 Great Unknown , LLC
# 221534                                                                              2011 Great Unknown , LLC
# 221533                                                                              2011 Great Unknown , LLC
# 2878652                                                                    ‰ ãÑ 2010 Cash Money Records Inc.
# 128408                                                               ‰ ãÑ 2014 Big Machine Label Group , LLC
# 128120                                                               ‰ ãÑ 2014 Big Machine Label Group , LLC
# 128264                                                               ‰ ãÑ 2014 Big Machine Label Group , LLC
# 127976                                                               ‰ ãÑ 2014 Big Machine Label Group , LLC
# 2877861                                                                    ‰ ãÑ 2010 Cash Money Records Inc.
# 511692   ‰ ãÑ 2009 Capitol Records Nashville . All rights reserved . Unauthorized reproduction is a viola...
# 2022849                     ‰ ãÑ 2015 Republic Records , a Division of UMG Recordings , Inc. ( Dot Records )
# 2022728                     ‰ ãÑ 2015 Republic Records , a Division of UMG Recordings , Inc. ( Dot Records )
# 2022607                     ‰ ãÑ 2015 Republic Records , a Division of UMG Recordings , Inc. ( Dot Records )
# 2022486                     ‰ ãÑ 2015 Republic Records , a Division of UMG Recordings , Inc. ( Dot Records )
# 1133349                                                                                       2004 BMG Music
# 1133350                                                                                       2004 BMG Music
# 1133356                                                                                       2004 BMG Music
# 1133352                                                                                       2004 BMG Music
# 1133353                                                                                       2004 BMG Music
# 1133354                                                                                       2004 BMG Music
# 1133351                                                                                       2004 BMG Music
# 1133355                                                                                       2004 BMG Music
# 1133338                                                                                       2004 BMG Music
# ...                                                                                                      ...
# 1567592                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1567598                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1567597                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1567617                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1567601                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1568290                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1568289                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1568287                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1567619                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1567591                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 941816                                       ‰ ãÑ 2009 Mercury Records , a Division of UMG Recordings , Inc.
# 1608045                                                                    ‰ ãÑ 2013 Cash Money Records Inc.
# 1569681                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1569022                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1569686                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1569002                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1569006                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1569005                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1569004                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1568999                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1568995                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1568994                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1568993                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1568986                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 1568981                  2014 Island Records , a division of UMG Recordings , Inc. / Safehouse Records , LLC
# 2942015  ‰ ãÑ 2014 Lana Del Rey under exclusive licence to Polydor Ltd. ( UK ) . Under exclusive licence ...
# 2941805  ‰ ãÑ 2014 Lana Del Rey under exclusive licence to Polydor Ltd. ( UK ) . Under exclusive licence ...
# 128225                                                               ‰ ãÑ 2014 Big Machine Label Group , LLC
# 128369                                                               ‰ ãÑ 2014 Big Machine Label Group , LLC
# 128081                                                               ‰ ãÑ 2014 Big Machine Label Group , LLC
#
#         ltable_Time ltable_Released                   rtable_Song_Name  \
# _id
# 221538         2:57       26-Apr-11                             Remark
# 221540         2:57       26-Apr-11                             Remark
# 221532         2:57       26-Apr-11                             Remark
# 221531         2:57       26-Apr-11                             Remark
# 221535         2:57       26-Apr-11                             Remark
# 221536         2:57       26-Apr-11                             Remark
# 221537         2:57       26-Apr-11                             Remark
# 221539         2:57       26-Apr-11                             Remark
# 221534         2:57       26-Apr-11                             Remark
# 221533         2:57       26-Apr-11                             Remark
# 2878652        2:46       15-Jun-10               Late Night Automatic
# 128408         2:50       14-Oct-14                              Smile
# 128120         2:50       14-Oct-14                              Smile
# 128264         2:50       14-Oct-14                              Smile
# 127976         2:50       14-Oct-14                              Smile
# 2877861        2:51       15-Jun-10                         Do n't Cry
# 511692         2:52        2-Oct-09                          Apologize
# 2022849        2:46       28-Aug-15                             Sierra
# 2022728        2:46       28-Aug-15                             Sierra
# 2022607        2:46       28-Aug-15                             Sierra
# 2022486        2:46       28-Aug-15                             Sierra
# 1133349        2:48            1994      I 'd Love To Change Your Name
# 1133350        2:48            1994      I 'd Love To Change Your Name
# 1133356        2:48            1994      I 'd Love To Change Your Name
# 1133352        2:48            1994      I 'd Love To Change Your Name
# 1133353        2:48            1994      I 'd Love To Change Your Name
# 1133354        2:48            1994      I 'd Love To Change Your Name
# 1133351        2:48            1994      I 'd Love To Change Your Name
# 1133355        2:48            1994      I 'd Love To Change Your Name
# 1133338        2:48            1994                 I Want My Rib Back
# ...             ...             ...                                ...
# 1567592        4:34       10-Nov-14            Nothing Would Be Better
# 1567598        4:34       10-Nov-14            Nothing Would Be Better
# 1567597        4:34       10-Nov-14            Nothing Would Be Better
# 1567617        4:34       10-Nov-14            Nothing Would Be Better
# 1567601        4:34       10-Nov-14            Nothing Would Be Better
# 1568290        4:34       10-Nov-14            Nothing Would Be Better
# 1568289        4:34       10-Nov-14            Nothing Would Be Better
# 1568287        4:34       10-Nov-14            Nothing Would Be Better
# 1567619        4:34       10-Nov-14            Nothing Would Be Better
# 1567591        4:34       10-Nov-14            Nothing Would Be Better
# 941816         3:33       16-Jun-09  Keep The Change ( Album Version )
# 1608045        4:27       24-Sep-13        Furthest Thing [ Explicit ]
# 1569681        4:34       10-Nov-14            Nothing Would Be Better
# 1569022        4:34       10-Nov-14            Nothing Would Be Better
# 1569686        4:34       10-Nov-14            Nothing Would Be Better
# 1569002        4:34       10-Nov-14            Nothing Would Be Better
# 1569006        4:34       10-Nov-14            Nothing Would Be Better
# 1569005        4:34       10-Nov-14            Nothing Would Be Better
# 1569004        4:34       10-Nov-14            Nothing Would Be Better
# 1568999        4:34       10-Nov-14            Nothing Would Be Better
# 1568995        4:34       10-Nov-14            Nothing Would Be Better
# 1568994        4:34       10-Nov-14            Nothing Would Be Better
# 1568993        4:34       10-Nov-14            Nothing Would Be Better
# 1568986        4:34       10-Nov-14            Nothing Would Be Better
# 1568981        4:34       10-Nov-14            Nothing Would Be Better
# 2942015        5:14       16-Jun-14                       Black Beauty
# 2941805        5:14       16-Jun-14                       Black Beauty
# 128225         3:05       14-Oct-14                           Sun Daze
# 128369         3:05       14-Oct-14                           Sun Daze
# 128081         3:05       14-Oct-14                           Sun Daze
#
#            rtable_Artist_Name                      rtable_Album_Name  \
# _id
# 221538         Rachel Platten                                Be Here
# 221540         Rachel Platten                                Be Here
# 221532         Rachel Platten                                Be Here
# 221531         Rachel Platten                                Be Here
# 221535         Rachel Platten                                Be Here
# 221536         Rachel Platten                                Be Here
# 221537         Rachel Platten                                Be Here
# 221539         Rachel Platten                                Be Here
# 221534         Rachel Platten                                Be Here
# 221533         Rachel Platten                                Be Here
# 2878652          Kevin Rudolf                             To The Sky
# 128408   Florida Georgia Line                          Anything Goes
# 128120   Florida Georgia Line                          Anything Goes
# 128264   Florida Georgia Line                          Anything Goes
# 127976   Florida Georgia Line                          Anything Goes
# 2877861          Kevin Rudolf                             To The Sky
# 511692             Luke Bryan                        Doin ' My Thing
# 2022849          Maddie & Tae                             Start Here
# 2022728          Maddie & Tae                             Start Here
# 2022607          Maddie & Tae                             Start Here
# 2022486          Maddie & Tae                             Start Here
# 1133349         Kenny Chesney                   In My Wildest Dreams
# 1133350         Kenny Chesney                   In My Wildest Dreams
# 1133356         Kenny Chesney                   In My Wildest Dreams
# 1133352         Kenny Chesney                   In My Wildest Dreams
# 1133353         Kenny Chesney                   In My Wildest Dreams
# 1133354         Kenny Chesney                   In My Wildest Dreams
# 1133351         Kenny Chesney                   In My Wildest Dreams
# 1133355         Kenny Chesney                   In My Wildest Dreams
# 1133338         Kenny Chesney                   In My Wildest Dreams
# ...                       ...                                    ...
# 1567592            Nick Jonas        Nick Jonas ( Deluxe ) [ Clean ]
# 1567598            Nick Jonas        Nick Jonas ( Deluxe ) [ Clean ]
# 1567597            Nick Jonas        Nick Jonas ( Deluxe ) [ Clean ]
# 1567617            Nick Jonas        Nick Jonas ( Deluxe ) [ Clean ]
# 1567601            Nick Jonas        Nick Jonas ( Deluxe ) [ Clean ]
# 1568290            Nick Jonas        Nick Jonas ( Deluxe ) [ Clean ]
# 1568289            Nick Jonas        Nick Jonas ( Deluxe ) [ Clean ]
# 1568287            Nick Jonas        Nick Jonas ( Deluxe ) [ Clean ]
# 1567619            Nick Jonas        Nick Jonas ( Deluxe ) [ Clean ]
# 1567591            Nick Jonas        Nick Jonas ( Deluxe ) [ Clean ]
# 941816         Holly Williams                           Here With Me
# 1608045                 Drake      Nothing Was The Same [ Explicit ]
# 1569681            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1569022            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1569686            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1569002            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1569006            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1569005            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1569004            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1568999            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1568995            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1568994            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1568993            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1568986            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 1568981            Nick Jonas     Nick Jonas ( Deluxe ) [ Explicit ]
# 2942015          Lana Del Rey  Ultraviolence ( Deluxe ) [ Explicit ]
# 2941805          Lana Del Rey  Ultraviolence ( Deluxe ) [ Explicit ]
# 128225   Florida Georgia Line                          Anything Goes
# 128369   Florida Georgia Line                          Anything Goes
# 128081   Florida Georgia Line                          Anything Goes
#
#                                      rtable_Genre rtable_Price  \
# _id
# 221538                                        Pop       $ 0.99
# 221540                                        Pop       $ 0.99
# 221532                                        Pop       $ 0.99
# 221531                                        Pop       $ 0.99
# 221535                                        Pop       $ 0.99
# 221536                                        Pop       $ 0.99
# 221537                                        Pop       $ 0.99
# 221539                                        Pop       $ 0.99
# 221534                                        Pop       $ 0.99
# 221533                                        Pop       $ 0.99
# 2878652  R&B , Rock , Rap Rock , Contemporary R&B       $ 0.99
# 128408                                    Country       $ 1.29
# 128120                                    Country       $ 1.29
# 128264                                    Country       $ 1.29
# 127976                                    Country       $ 1.29
# 2877861  R&B , Rock , Rap Rock , Contemporary R&B       $ 0.99
# 511692                                    Country       $ 1.29
# 2022849                                   Country       $ 1.29
# 2022728                                   Country       $ 1.29
# 2022607                                   Country       $ 1.29
# 2022486                                   Country       $ 1.29
# 1133349                                   Country       $ 0.99
# 1133350                                   Country       $ 0.99
# 1133356                                   Country       $ 0.99
# 1133352                                   Country       $ 0.99
# 1133353                                   Country       $ 0.99
# 1133354                                   Country       $ 0.99
# 1133351                                   Country       $ 0.99
# 1133355                                   Country       $ 0.99
# 1133338                                   Country       $ 0.99
# ...                                           ...          ...
# 1567592                                       Pop       $ 1.29
# 1567598                                       Pop       $ 1.29
# 1567597                                       Pop       $ 1.29
# 1567617                                       Pop       $ 1.29
# 1567601                                       Pop       $ 1.29
# 1568290                                       Pop       $ 1.29
# 1568289                                       Pop       $ 1.29
# 1568287                                       Pop       $ 1.29
# 1567619                                       Pop       $ 1.29
# 1567591                                       Pop       $ 1.29
# 941816                                    Country       $ 0.99
# 1608045                             Rap & Hip-Hop       $ 1.29
# 1569681                                       Pop       $ 1.29
# 1569022                                       Pop       $ 1.29
# 1569686                                       Pop       $ 1.29
# 1569002                                       Pop       $ 1.29
# 1569006                                       Pop       $ 1.29
# 1569005                                       Pop       $ 1.29
# 1569004                                       Pop       $ 1.29
# 1568999                                       Pop       $ 1.29
# 1568995                                       Pop       $ 1.29
# 1568994                                       Pop       $ 1.29
# 1568993                                       Pop       $ 1.29
# 1568986                                       Pop       $ 1.29
# 1568981                                       Pop       $ 1.29
# 2942015                          Alternative Rock       $ 1.29
# 2941805                          Alternative Rock       $ 1.29
# 128225                                    Country       $ 1.29
# 128369                                    Country       $ 1.29
# 128081                                    Country       $ 1.29
#
#                                                                                             rtable_CopyRight  \
# _id
# 221538                                                                              2014 Great Unknown , LLC
# 221540                                                                              2014 Great Unknown , LLC
# 221532                                                                              2014 Great Unknown , LLC
# 221531                                                                              2014 Great Unknown , LLC
# 221535                                                                              2014 Great Unknown , LLC
# 221536                                                                              2014 Great Unknown , LLC
# 221537                                                                              2014 Great Unknown , LLC
# 221539                                                                              2014 Great Unknown , LLC
# 221534                                                                              2014 Great Unknown , LLC
# 221533                                                                              2014 Great Unknown , LLC
# 2878652                                                                   ( C ) 2010 Cash Money Records Inc.
# 128408              ( C ) 2014 Republic Records , a Division of UMG Recordings , Inc. ( Republic Nashville )
# 128120              ( C ) 2014 Republic Records , a Division of UMG Recordings , Inc. ( Republic Nashville )
# 128264              ( C ) 2014 Republic Records , a Division of UMG Recordings , Inc. ( Republic Nashville )
# 127976              ( C ) 2014 Republic Records , a Division of UMG Recordings , Inc. ( Republic Nashville )
# 2877861                                                                   ( C ) 2010 Cash Money Records Inc.
# 511692                                                                  ( C ) 2009 Capitol Records Nashville
# 2022849                    ( C ) 2015 Republic Records , a Division of UMG Recordings , Inc. ( Dot Records )
# 2022728                    ( C ) 2015 Republic Records , a Division of UMG Recordings , Inc. ( Dot Records )
# 2022607                    ( C ) 2015 Republic Records , a Division of UMG Recordings , Inc. ( Dot Records )
# 2022486                    ( C ) 2015 Republic Records , a Division of UMG Recordings , Inc. ( Dot Records )
# 1133349                                                                                     ( p ) Moda Black
# 1133350                                                                                     ( p ) Moda Black
# 1133356                                                                                     ( p ) Moda Black
# 1133352                                                                                     ( p ) Moda Black
# 1133353                                                                                     ( p ) Moda Black
# 1133354                                                                                     ( p ) Moda Black
# 1133351                                                                                     ( p ) Moda Black
# 1133355                                                                                     ( p ) Moda Black
# 1133338                                                                                     ( p ) Moda Black
# ...                                                                                                      ...
# 1567592                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1567598                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1567597                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1567617                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1567601                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1568290                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1568289                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1568287                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1567619                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1567591                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 941816                                      ( C ) 2008 Mercury Records , a Division of UMG Recordings , Inc.
# 1608045                                                                   ( C ) 2013 Cash Money Records Inc.
# 1569681                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1569022                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1569686                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1569002                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1569006                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1569005                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1569004                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1568999                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1568995                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1568994                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1568993                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1568986                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 1568981                ( C ) 2014 Island Records/Safehouse Records LLC , a division of UMG Recordings , Inc.
# 2942015  ( C ) 2014 Lana Del Rey under exclusive licence to Polydor Ltd. ( UK ) . Under exclusive licence...
# 2941805  ( C ) 2014 Lana Del Rey under exclusive licence to Polydor Ltd. ( UK ) . Under exclusive licence...
# 128225              ( C ) 2014 Republic Records , a Division of UMG Recordings , Inc. ( Republic Nashville )
# 128369              ( C ) 2014 Republic Records , a Division of UMG Recordings , Inc. ( Republic Nashville )
# 128081              ( C ) 2014 Republic Records , a Division of UMG Recordings , Inc. ( Republic Nashville )
#
#         rtable_Time      rtable_Released
# _id
# 221538         2:57      April 26 , 2011
# 221540         2:57      April 26 , 2011
# 221532         2:57      April 26 , 2011
# 221531         2:57      April 26 , 2011
# 221535         2:57      April 26 , 2011
# 221536         2:57      April 26 , 2011
# 221537         2:57      April 26 , 2011
# 221539         2:57      April 26 , 2011
# 221534         2:57      April 26 , 2011
# 221533         2:57      April 26 , 2011
# 2878652        2:47       June 15 , 2010
# 128408         2:49    October 14 , 2014
# 128120         2:49    October 14 , 2014
# 128264         2:49    October 14 , 2014
# 127976         2:49    October 14 , 2014
# 2877861        2:52       June 15 , 2010
# 511692         2:51     October 2 , 2009
# 2022849        2:45     August 28 , 2015
# 2022728        2:45     August 28 , 2015
# 2022607        2:45     August 28 , 2015
# 2022486        2:45     August 28 , 2015
# 1133349        2:48       July 27 , 2004
# 1133350        2:48       July 27 , 2004
# 1133356        2:48       July 27 , 2004
# 1133352        2:48       July 27 , 2004
# 1133353        2:48       July 27 , 2004
# 1133354        2:48       July 27 , 2004
# 1133351        2:48       July 27 , 2004
# 1133355        2:48       July 27 , 2004
# 1133338        2:54       July 27 , 2004
# ...             ...                  ...
# 1567592        4:34   November 10 , 2014
# 1567598        4:34   November 10 , 2014
# 1567597        4:34   November 10 , 2014
# 1567617        4:34   November 10 , 2014
# 1567601        4:34   November 10 , 2014
# 1568290        4:34   November 10 , 2014
# 1568289        4:34   November 10 , 2014
# 1568287        4:34   November 10 , 2014
# 1567619        4:34   November 10 , 2014
# 1567591        4:34   November 10 , 2014
# 941816         3:34       June 16 , 2009
# 1608045        4:27  September 24 , 2013
# 1569681        4:34   November 10 , 2014
# 1569022        4:34   November 10 , 2014
# 1569686        4:34   November 10 , 2014
# 1569002        4:34   November 10 , 2014
# 1569006        4:34   November 10 , 2014
# 1569005        4:34   November 10 , 2014
# 1569004        4:34   November 10 , 2014
# 1568999        4:34   November 10 , 2014
# 1568995        4:34   November 10 , 2014
# 1568994        4:34   November 10 , 2014
# 1568993        4:34   November 10 , 2014
# 1568986        4:34   November 10 , 2014
# 1568981        4:34   November 10 , 2014
# 2942015        5:14       June 17 , 2014
# 2941805        5:14       June 17 , 2014
# 128225         3:04    October 14 , 2014
# 128369         3:04    October 14 , 2014
# 128081         3:04    October 14 , 2014
#
# [2787 rows x 19 columns]
