# %%
import deepmatcher as dm

# %%
train, validation, test = dm.process(
    path='~/emdata/structured_data_blocking/Abt-Buy/',
    train='train_dm.csv',
    validation='valid_dm.csv',
    test='test_dm.csv',
    ignore_columns=('left_id', 'right_id'),
    include_lengths=True,
    auto_rebuild_cache=True,
    pca=True,
    cache='sid_cache.pth')

# %%
hybrid_model = dm.MatchingModel(attr_summarizer='hybrid')
hybrid_model.run_train(
    train,
    validation,
    label_smoothing=0.05,
    batch_size=16,
    epochs=15,
    best_save_path='/tmp/hybrid_ab2.pth',
    pos_weight=1.5)
# Out:
# * Number of trainable parameters: 7133105
# =>  TRAIN epoch 1 :
# HBox(children=(IntProgress(value=0, max=71), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-969addf773e9> in <module>()
#       7     epochs=15,
#       8     best_save_path='/tmp/hybrid_ab2.pth',
# ----> 9     pos_weight=1.5)
#
# /afs/cs.wisc.edu/u/s/i/sidharth/private/deepmatcher/deepmatcher/models/core.py in run_train(self, *args, **kwargs)
#     179
#     180     def run_train(self, *args, **kwargs):
# --> 181         return Runner.train(self, *args, **kwargs)
#     182
#     183     def run_eval(self, *args, **kwargs):
#
# /afs/cs.wisc.edu/u/s/i/sidharth/private/deepmatcher/deepmatcher/runner.py in train(model, train_dataset, validation_dataset, epochs, criterion, optimizer, pos_weight, label_smoothing, best_save_path, save_every_prefix, save_every_freq, **kwargs)
#     303             model.epoch = epoch
#     304             Runner._run(
# --> 305                 'TRAIN', model, train_dataset, criterion, optimizer, train=True, **kwargs)
#     306
#     307             score = Runner._run('EVAL', model, validation_dataset, train=False, **kwargs)
#
# /afs/cs.wisc.edu/u/s/i/sidharth/private/deepmatcher/deepmatcher/runner.py in _run(run_type, model, dataset, criterion, optimizer, train, device, save_path, batch_size, num_data_workers, batch_callback, epoch_callback, progress_style, log_freq, sort_in_buckets, return_predictions, **kwargs)
#     210             datatime += batch_start - batch_end
#     211
# --> 212             output = model(batch)
#     213
#     214             # from torchviz import make_dot, make_dot_from_trace
#
# ~/anaconda2/envs/labpy36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /afs/cs.wisc.edu/u/s/i/sidharth/private/deepmatcher/deepmatcher/models/core.py in forward(self, input)
#     149             left, right = self.text_fields[name]
#     150             left_summary, right_summary = self.attr_summarizers[name](embeddings[left],
# --> 151                                                                       embeddings[right])
#     152             left_summary, right_summary = left_summary.data, right_summary.data
#     153             if self.attr_condensors:
#
# ~/anaconda2/envs/labpy36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /afs/cs.wisc.edu/u/s/i/sidharth/private/deepmatcher/deepmatcher/models/modules.py in forward(self, input, *args, **kwargs)
#      66             self._initialized = True
#      67
# ---> 68         return self._forward(input, *args, **kwargs)
#      69
#      70     def expect_signature(self, signature):
#
# /afs/cs.wisc.edu/u/s/i/sidharth/private/deepmatcher/deepmatcher/models/core.py in _forward(self, left_input, right_input)
#     224         right_aggregator_context = left_input
#     225
# --> 226         left_aggregated = self.word_aggregator(left_compared, left_aggregator_context)
#     227         right_aggregated = self.word_aggregator(right_compared, right_aggregator_context)
#     228         return left_aggregated, right_aggregated
#
# ~/anaconda2/envs/labpy36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /afs/cs.wisc.edu/u/s/i/sidharth/private/deepmatcher/deepmatcher/models/modules.py in forward(self, input, *args, **kwargs)
#      66             self._initialized = True
#      67
# ---> 68         return self._forward(input, *args, **kwargs)
#      69
#      70     def expect_signature(self, signature):
#
# /afs/cs.wisc.edu/u/s/i/sidharth/private/deepmatcher/deepmatcher/models/word_aggregators.py in _forward(self, input_with_meta, context_with_meta)
#      71         # Dims: batch x len1
#      72         raw_scores = self.scoring_network(
# ---> 73             self.input_context_comparison_network(concatenated)).squeeze(2)
#      74
#      75         alignment_scores = self.score_dropout(raw_scores)
#
# ~/anaconda2/envs/labpy36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /afs/cs.wisc.edu/u/s/i/sidharth/private/deepmatcher/deepmatcher/models/modules.py in forward(self, input, *args, **kwargs)
#      66             self._initialized = True
#      67
# ---> 68         return self._forward(input, *args, **kwargs)
#      69
#      70     def expect_signature(self, signature):
#
# /afs/cs.wisc.edu/u/s/i/sidharth/private/deepmatcher/deepmatcher/models/modules.py in _forward(self, input)
#     508
#     509         for transform, bypass in zip(self.transforms, self.bypass_networks):
# --> 510             new_output = transform(output)
#     511             if self.non_linearity:
#     512                 new_output = getattr(F, self.non_linearity)(new_output)
#
# ~/anaconda2/envs/labpy36/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# ~/anaconda2/envs/labpy36/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def __repr__(self):
#
# ~/anaconda2/envs/labpy36/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     835         return torch.addmm(bias, input, weight.t())
#     836
# --> 837     output = input.matmul(weight.t())
#     838     if bias is not None:
#     839         output += bias
#
# ~/anaconda2/envs/labpy36/lib/python3.6/site-packages/torch/autograd/variable.py in matmul(self, other)
#     384
#     385     def matmul(self, other):
# --> 386         return torch.matmul(self, other)
#     387
#     388     def resize(self, *sizes):
#
# ~/anaconda2/envs/labpy36/lib/python3.6/site-packages/torch/functional.py in matmul(tensor1, tensor2, out)
#     190
#     191         if out is None or not out.is_contiguous():
# --> 192             output = torch.mm(tensor1, tensor2)
#     193         else:
#     194             output = torch.mm(tensor1, tensor2, out=out)
#
# KeyboardInterrupt:
